# %% [markdown]
# # Introdução - movimento Browniano geométrico
#
# Um processo estocástico $\{S_t\}_{t \geq 0}$ pode ser modelado como um mBg (movimento Browniano geométrico) se satisfazer a  SDE:
#
# $$dS_t = \mu S_t dt + \sigma S_t dB_t$$
#
# Neste caso, a solução da SDE acima é dada por $S_t = S_0 e^{X(t)}$, onde $X(t) = \left(\mu - \frac{\sigma^2}{2} \right)t + \sigma B_t$ e $B_t$ é um movimento Browniano, ou seja, $X(t)$ é um movimento Browniano com drift $\left(\mu - \frac{\sigma^2}{2}\right)$.
#
# ## Propriedade
#
# $\quad$ i. $\lim_{t \to +\infty} \mathbb{P}\left(S_t = +\infty \mid \mu - \frac{\sigma^2}{2} > 0\right) = 1$.
#
#
# # Estratégia
#
# O backtest abaixo tem a seguinte ideia, mensalmente iremos estimar os parâmetros do modelo movimento Browniano geométrico e iremos rankear os ativos do maior para o menor com base na seguinte fórmula:
#
# $$\frac{\mu}{\sigma^2}$$
#
# A ideia é que queremos os ativos com maior drift e menor volatilidade e aproveitar-se da propriedade i citada anteriormente na introdução. Obsreve que $\mu$ e $\sigma$ são os parâmetros do modelo. Selecionaremos o top n ativos com maior ranking e aplicaremos a fronteira eficiente nesse conjunto, a estratégia fará o rebalanceamento dos ativos mensalmente.

# %%
from __future__ import (absolute_import, division, print_function,
                        unicode_literals)
from collections import OrderedDict

#library for filtering signals
import statsmodels.api as sm

#Numerical operations
import numpy as np
from numpy import log as ln
from math import floor, isnan

#Symbolic operations
import sympy as sy
from sympy import symbols, lambdify
from sympy.functions.elementary.exponential import exp

#Datetime operations
import datetime

#Import backtrader platform
import backtrader as bt
import backtrader.analyzers as btanalyzers

#Module to analyze portfolio
import pyfolio as pf

#Ploting library
import matplotlib.pyplot as plt

#operating system library
import os

#Optimizations
from scipy.optimize import minimize, Bounds, LinearConstraint
from scipy.stats import norm as N

#portfolio analyzer
import quantstats as qs

#data analysis library
import pandas as pd

#debugging library
from ipdb import set_trace

class Portfolio():
    """
        Class portfolio, retrieve optimal portfolio weights based on Markowitz efficient frontier model.

        Inputs:
            μ - assets log return vector
            Σ - assets variance-covariance matrix
            minimize_method - method to optimize (std = standard deviation, neg_sharpe = negative sharpe)
            long_only(True/False) - allows short position if False (not implemented)
    """

    def __init__(self, μ, Σ, premiumRisk=0, minimize_method='std', long_only=True):
        
        n = len(μ)
        
        self.n = n
        self.μ = μ
        self.Σ = Σ
        self.premiumRisk = 0
        self.n_days = 1
        self.minimize_method = minimize_method
        self.premiumRisk = premiumRisk
        self.set_long_only = long_only
    
    def n_bound(self,n):
        return [(0,None) for i in range(n)]
    
    def std(self, w, μ, Σ):
        return (np.dot(w.T, np.dot(Σ, w)))**0.5
    
    def neg_sharpe(self, w, μ, Σ):
        return -(np.dot(w.T,μ))/((np.dot(w.T, np.dot(Σ, w)))**0.5)
    
    
    def optimize(self):
        μ = self.μ
        Σ = self.Σ
        n = self.n
        if self.minimize_method=='std':
            f=self.std
        if self.minimize_method=='neg_sharpe':
            f=self.neg_sharpe
            
        #Initial Guess
        w = np.random.rand(n)
        w /= np.sum(w)
        
        #Model Constraints

        bounds = self.n_bound(n)
        constraints = LinearConstraint(np.ones(n), lb=1, ub=1)
        
        #Optimization
        optimization = minimize(f, w, args=(μ, Σ), 
                        method='SLSQP', 
                        bounds=bounds, constraints=constraints)

        #Risk, Return Calculations
        optW = optimization['x']
        optReturn = np.dot(optW.T,self.μ)
        optRisk = np.sqrt(np.dot(optW.T, np.dot(self.Σ, optW)))
        
        self.optRisk = optRisk
        self.optReturn = optReturn
        
        return optW, optRisk, optReturn
        
    
    def plot(self):
        #Creation of a markowitz graph representation
        n = self.n
        PortfolioReturn = []
        PortfolioRisk = []
        for t in range(10000):
            ω = np.random.rand(n)
            ω /= (np.sum(ω)*1)
            Return = np.dot(ω.T, self.μ)
            Risk = np.sqrt(np.dot(ω.T, np.dot(self.Σ, ω)))
            PortfolioReturn.append(Return)
            PortfolioRisk.append(Risk)
        fig, ax = plt.subplots(figsize=(16,10), facecolor=(0.75, 0.75, 0.75))
        
        #plot
        ax.plot(PortfolioRisk, PortfolioReturn, 'o', label='Portfolios')
        ax.plot(self.optRisk, self.optReturn, 'bo', label='Optimal Point')
        
        #aesthetics
        ax.set_facecolor((0.1, 0.1, 0.1))
        ax.grid(True)
        ax.set_ylabel('Expected Return')
        ax.set_xlabel('Standard Deviation')
        ax.legend()
        
        plt.show()

class gBm(bt.Indicator):
    """
        Geometric Brownian Motion model.
                dS_t = μ S_t dt + σ S_t dB_t
        
        Crescimento Exponencial. 
        o modelo tem um fit melhor para growth stocks como AAPL, TSLA, MGLU3, PRIO3 etc i.e.
        para ativos que tem um Crescimento Exponencial
    """
    lines = ('m', 'σ', 'μ', 'var', 'sl')
    params = dict(size=2**9+1, 
                  sl_quantil=0.1, 
                  sl_look_forward=5)
    
    def __init__(self):
        self.addminperiod(self.p.size)
        
    def next(self):
        self.S = self.data.close.get(0, size=self.p.size)
        self.estimateParams()
        

        self.lines.m[0] = self.m
        self.lines.σ[0] = self.σ
        self.lines.μ[0] = self.μ
        self.lines.var[0] = self.Var(self.p.sl_look_forward)
        self.lines.sl[0] = self.q(self.p.sl_quantil, self.p.sl_look_forward)
        

    
    def estimateParams(self):
        """
        Referência:
        "Estimation of Geometric Brownian Motion Parameters for Oil Price Analysis" C. Jakob et al.
        """
        S = self.S
        X = np.diff(np.log(S), n=1)
        m = X.mean() #mean
        σ = X.std() #standard deviation
        μ = m + ((σ**2)/2) #drift
        n = len(S)

        self.m = m
        self.σ = σ
        self.μ = μ
        self.n = n
    
    def E(self, t):
        """
        Referência:
        Ross, Sheldon M. (2014). "Variations on Brownian Motion".
        Introduction to Probability Models (11th ed.).
        """
        S = self.S
        S0 = S[-1]
        μ = self.μ
        return S0*np.exp(μ*t)
    
    def Var(self, t):
        """
        Referência:
        Ross, Sheldon M. (2014). "Variations on Brownian Motion". 
        Introduction to Probability Models (11th ed.).
        """
        S = self.S
        S0 = S[-1]
        μ = self.μ
        σ = self.σ
        return (S0**2)*np.exp(2*μ*t)*(np.exp((σ**2)*t) - 1)
    
    def q(self, p, t):
        """
         quantil de St/S0 o qual é definido como:
                q(p) = exp( (μ - σ**2/2)*t + σ*np.sqrt(t)*inv_Φ(p))
         p ∈ (0,1)
        """
        #assert p>0 and p<1
        #assert type(t)==int

        σ = self.σ
        μ = self.μ
        
        mean = (μ - (σ**2/2))*t
        var = σ**2*t
        return np.exp(mean +  np.sqrt(var)*N.ppf(p, 0, 1))

class momentumStrat(bt.Strategy):
    """
        strategy class
    """
    params = dict(gBmSize=2**8+1, #number of observations to use in backtest to estimate parameters
                  enableLog=True, #enable log of buy and sell of assets
                  exposure=1, #exposure to the market
                  rebal_monthday=1, #which day in month to do the rebalancing
                  stocks_holding=10) #Max number of stocks holding 
    
    def __init__(self):
        self.order = None #variable to track pending orders
        acoes = self.datas 
        
        #construct line objects of gBm data
        gBms = [gBm(d, size=self.p.gBmSize) for d in acoes]
        driftAcoes = [gBm.μ for gBm in gBms]
        volatAcoes = [gBm.σ for gBm in gBms]
        
        #construct a line object of ranks 
        self.rank = {d:drift/volat for d, drift, volat in zip(acoes, driftAcoes, volatAcoes)}
        
        self.driftAcoes = {d:drift for d, drift in zip(acoes, driftAcoes)}
        self.volatAcoes = {d:volat for d, volat in zip(acoes, volatAcoes)}
        
        #create a timer to execute the strategy montly
        self.add_timer(
            when=bt.Timer.SESSION_START,
            monthdays=[self.p.rebal_monthday],
            monthcarry=True  # if a day isn't there, execute on the next
        )
    
    def notify_order(self, order):
        '''Notify if an orde was executed/submited or not'''
    
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(
                    'BUY EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                    (order.executed.price,
                     order.executed.value,
                     order.executed.comm))
                
                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
                
            else:  # Sell
                
                self.log('SELL EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                         (order.executed.price,
                          order.executed.value,
                          order.executed.comm))

            self.bar_executed = len(self)
        
        elif order.status==order.Canceled:
            self.log('Order Canceled. Price: {}'.format(order.price))
        elif order.status==order.Margin:
            self.log('Order Margin. Price: {}'.format(order.price))
        elif order.status==order.Rejected:
            self.log('Order Rejected. Price: {}'.format(order.price))

        self.order = None

    def log(self, txt, dt=None, doprint=False):
        '''Logging function fot this strategy'''
        if self.params.enableLog or doprint:
            dt = dt or self.datas[0].datetime.date(0)
            print('%s, %s' % (dt.isoformat(), txt))
    
    def getPortfolioParameters(self, datas:list):
        '''Get portfolio assets log returns vector and assets variance-covariance matrix'''
        S = np.column_stack(tuple(np.array(d).T for d in map(lambda x: x.close.get(0, self.p.gBmSize), datas)))
        S0 = S[0]
        X = np.diff(np.log(np.divide(S,S0)), n=1, axis=0)
        μ = X.mean(axis=0)
        Σ = np.cov(X, rowvar=False)
        
        n = len(datas)

        return μ, Σ
    
    def notify_timer(self, timer, when, *args, **kwargs):
        '''this function is called monthly, it is our strategy logic'''
        l = len(self)
        if l < self.p.gBmSize or self.order:
            return
        
        rank = {d:rank for (d, rank) in self.rank.items() if d.close.get(0, self.p.gBmSize)}

        ranks = sorted(
            rank.items(),  # get the (d, rank), pair
            key=lambda x: x[1][0],  # use rank (elem 1) and current time "0"
            reverse=True,  # highest ranked 1st ... please
        )
        

        top_ranks = ranks[:self.p.stocks_holding]
        datas = [data for (data, rank) in top_ranks]
        μ, Σ = self.getPortfolioParameters(datas)
        portfolio = Portfolio(μ, Σ, minimize_method='neg_sharpe')
        w, Risk, Return = portfolio.optimize()
        #portfolio.plot()
        
        opt_portfolio = [(data,weight) for (data,weight) in zip(datas,w)]
        current_positions = [d for d, pos in self.getpositions().items() if pos]
 
        
        
        #if we're not in market
        if len(current_positions)==0:
            for (d,weight) in opt_portfolio:
                if weight!=0:
                    self.order = self.order_target_percent(d, target=weight)
                    self.log('Buying: {} /---/ Rank: {:.4f} /---/ Weight: {:.3f}'.format(d._name, 
                                                                                   rank[d][0], 
                                                                                   weight))
            return
                
        
        #if we're in market
        else:
            
            # remove those no longer top ranked
            # do this first to issue sell orders and free cash
            for d in (d for d in current_positions if d not in datas):
                self.log('Closing: {} /---/ Rank: {:.4f}'.format(d._name, rank[d][0]))
                self.order_target_percent(d, target=0.0)
            
            # rebalance those already top ranked and still there
            for d in (d for d in current_positions if d in datas):
                i = datas.index(d)
                self.log('Rebalancing: {} /---/ Rank: {:.4f} /---/ Weight: {:.3f}'.format(d._name,
                                                                                     rank[d][0],
                                                                                     w[i]))
                self.order_target_percent(d, target=w[i])
                del datas[i]  # remove it, to simplify next iteration
                w = np.delete(w, i)
                
            # issue a target order for the newly top ranked stocks
            # do this last, as this will generate buy orders consuming cash
            for i,d in enumerate(datas):

                if w[i]!=0:
                    self.log('Buying: {} /---/ Rank: {:.4f} /---/ Weight: {:.3f}'.format(d._name,
                                                                                         rank[d][0],
                                                                                         w[i]))
                    self.order_target_percent(d, target=w[i])
                else:
                    continue

    def stop(self):
        self.log('Ending Value %.2f' %
                 (self.broker.getvalue()), doprint=True)
    
def runStrat(in_start, in_end, wf=False, best_set=None):
    '''create cerebro instance, set cash, add data, add strategy and run it'''
    cerebro = bt.Cerebro()
    
    #Set cash value
    cerebro.broker.set_cash(100000)
    
    #Set commission modelo
    cerebro.broker.setcommission(commission=0)
    
    cerebro.broker.set_checksubmit(False)
    
    
    data_font = 'data'
    
    #Adding data
    start=datetime.datetime.strptime(in_start, '%Y-%m-%d')
    end=datetime.datetime.strptime(in_end, '%Y-%m-%d')
    

    files = os.listdir(data_font)
    
    for file in files:
        #print(file)
        datapath='{}//'.format(data_font)+file
        data = bt.feeds.YahooFinanceCSVData(dataname=datapath,
                                            fromdate=start,
                                            todate=end,
                                            reverse=False)
        cerebro.adddata(data)
    
    
    
    #Add analyzers
    cerebro.addanalyzer(bt.analyzers.PyFolio, _name='pyfolio')
    cerebro.addanalyzer(btanalyzers.SharpeRatio, _name='sharpe')
    
    #Add Strategy    
    if wf:
        cerebro.addstrategy(momentumStrat, wf=wf)
    else:
        cerebro.addstrategy(momentumStrat)
    
    #Run Algo
    results = cerebro.run(maxcpus=1)

    
    #Plot results
    #cerebro.plot()
    
    return results

def analyzeStrat(results, live):
    '''analyze strategy results'''
    strat = results[0]
    pyfoliozer = strat.analyzers.getbyname('pyfolio')
    returns, positions, transactions, gross_lev = pyfoliozer.get_pf_items()
    
    # extend pandas functionality with metrics, etc.
    qs.extend_pandas()
    returns.index = pd.to_datetime(returns.index.astype(str).str[:10])
    qs.reports.full(returns, '^BVSP')

if __name__=='__main__':
    live = '2021-01-01'
    r = runStrat('2005-01-03', '2021-06-02')
    analyzeStrat(r, live)
# Out:
# 2021-06-01, Buying: BBDC4.SA /---/ Rank: 0.2035 /---/ Weight: 0.386
# 2021-06-01, Buying: PETR4.SA /---/ Rank: 0.1703 /---/ Weight: 0.237
# 2021-06-01, Buying: VIVT3.SA /---/ Rank: 0.1534 /---/ Weight: 0.000
# 2021-06-01, Buying: LAME4.SA /---/ Rank: 0.1468 /---/ Weight: 0.120
# 2021-06-01, Buying: CPFE3.SA /---/ Rank: 0.1323 /---/ Weight: 0.121
# 2021-06-01, Buying: TIMS3.SA /---/ Rank: 0.1234 /---/ Weight: 0.027
# 2021-06-01, Buying: CMIG4.SA /---/ Rank: 0.1202 /---/ Weight: 0.000
# 2021-06-01, Buying: ITUB4.SA /---/ Rank: 0.1189 /---/ Weight: 0.000
# 2021-06-01, Buying: CCRO3.SA /---/ Rank: 0.1158 /---/ Weight: 0.108
# 2021-06-01, BUY EXECUTED, Price: 7.99, Cost: 38687.58, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 16.00, Cost: 23568.00, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 3925.22, Cost: 11775.66, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 7.03, Cost: 12105.66, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 2.96, Cost: 11028.96, Comm 0.00
# 2021-06-01, Closing: CCRO3.SA /---/ Rank: 0.1008
# 2021-06-01, Rebalancing: BBDC4.SA /---/ Rank: 0.1628 /---/ Weight: 0.249
# 2021-06-01, Rebalancing: CPFE3.SA /---/ Rank: 0.1180 /---/ Weight: 0.152
# 2021-06-01, Rebalancing: LAME4.SA /---/ Rank: 0.1420 /---/ Weight: 0.179
# 2021-06-01, Rebalancing: PETR4.SA /---/ Rank: 0.1306 /---/ Weight: 0.115
# 2021-06-01, Buying: ITSA4.SA /---/ Rank: 0.1390 /---/ Weight: 0.018
# 2021-06-01, Buying: NTCO3.SA /---/ Rank: 0.1119 /---/ Weight: 0.152
# 2021-06-01, Buying: EGIE3.SA /---/ Rank: 0.1101 /---/ Weight: 0.130
# 2021-06-01, Buying: TIMS3.SA /---/ Rank: 0.1052 /---/ Weight: 0.005
# 2021-06-01, SELL EXECUTED, Price: 2.71, Cost: 11028.96, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 8.31, Cost: 14310.09, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 7.57, Cost: 2551.09, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 4348.19, Cost: 4348.19, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 15.53, Cost: 11488.00, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 3.80, Cost: 1881.00, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 9.79, Cost: 15536.73, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 5.90, Cost: 13292.70, Comm 0.00
# 2021-06-01, Closing: EGIE3.SA /---/ Rank: 0.0943
# 2021-06-01, Rebalancing: BBDC4.SA /---/ Rank: 0.1342 /---/ Weight: 0.054
# 2021-06-01, Rebalancing: CPFE3.SA /---/ Rank: 0.1265 /---/ Weight: 0.205
# 2021-06-01, Rebalancing: ITSA4.SA /---/ Rank: 0.1425 /---/ Weight: 0.179
# 2021-06-01, Rebalancing: LAME4.SA /---/ Rank: 0.1208 /---/ Weight: 0.103
# 2021-06-01, Rebalancing: NTCO3.SA /---/ Rank: 0.1132 /---/ Weight: 0.216
# 2021-06-01, Rebalancing: PETR4.SA /---/ Rank: 0.1268 /---/ Weight: 0.140
# 2021-06-01, Buying: BBAS3.SA /---/ Rank: 0.1157 /---/ Weight: 0.062
# 2021-06-01, Buying: CPLE6.SA /---/ Rank: 0.1080 /---/ Weight: 0.005
# 2021-06-01, Buying: TIMS3.SA /---/ Rank: 0.1021 /---/ Weight: 0.036
# 2021-06-01, SELL EXECUTED, Price: 6.21, Cost: 13292.70, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 7.32, Cost: 18361.02, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 6.98, Cost: 6323.88, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 3.95, Cost: 15950.10, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 4471.92, Cost: 4030.96, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 10.95, Cost: 4270.50, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 15.22, Cost: 2435.20, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 7.95, Cost: 6232.80, Comm 0.00
# 2021-06-01, Closing: NTCO3.SA /---/ Rank: 0.1066
# 2021-06-01, Rebalancing: BBAS3.SA /---/ Rank: 0.1332 /---/ Weight: 0.117
# 2021-06-01, Rebalancing: BBDC4.SA /---/ Rank: 0.1408 /---/ Weight: 0.014
# 2021-06-01, Rebalancing: CPFE3.SA /---/ Rank: 0.1243 /---/ Weight: 0.154
# 2021-06-01, Rebalancing: ITSA4.SA /---/ Rank: 0.1519 /---/ Weight: 0.086
# 2021-06-01, Rebalancing: LAME4.SA /---/ Rank: 0.1286 /---/ Weight: 0.141
# 2021-06-01, Rebalancing: PETR4.SA /---/ Rank: 0.1518 /---/ Weight: 0.197
# 2021-06-01, Buying: AMER3.SA /---/ Rank: 0.1686 /---/ Weight: 0.246
# 2021-06-01, Buying: GGBR4.SA /---/ Rank: 0.1412 /---/ Weight: 0.000
# 2021-06-01, Buying: BRAP4.SA /---/ Rank: 0.1241 /---/ Weight: 0.046
# 2021-06-01, SELL EXECUTED, Price: 10.56, Cost: 19807.23, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 8.90, Cost: 4975.10, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 7.31, Cost: 4498.37, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 7.03, Cost: 5264.62, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 3.97, Cost: 9259.74, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 16.27, Cost: 4994.89, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 55.02, Cost: 24648.96, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 13.70, Cost: 4562.10, Comm 0.00
# 2021-06-01, Rebalancing: AMER3.SA /---/ Rank: 0.1606 /---/ Weight: 0.205
# 2021-06-01, Rebalancing: BBAS3.SA /---/ Rank: 0.1072 /---/ Weight: 0.035
# 2021-06-01, Rebalancing: BBDC4.SA /---/ Rank: 0.1190 /---/ Weight: 0.059
# 2021-06-01, Rebalancing: BRAP4.SA /---/ Rank: 0.1309 /---/ Weight: 0.085
# 2021-06-01, Rebalancing: CPFE3.SA /---/ Rank: 0.1174 /---/ Weight: 0.138
# 2021-06-01, Rebalancing: ITSA4.SA /---/ Rank: 0.1236 /---/ Weight: 0.000
# 2021-06-01, Rebalancing: LAME4.SA /---/ Rank: 0.1137 /---/ Weight: 0.036
# 2021-06-01, Rebalancing: PETR4.SA /---/ Rank: 0.1374 /---/ Weight: 0.188
# 2021-06-01, Buying: RAIL3.SA /---/ Rank: 0.1376 /---/ Weight: 0.253
# 2021-06-01, Buying: GOAU4.SA /---/ Rank: 0.1296 /---/ Weight: 0.000
# 2021-06-01, SELL EXECUTED, Price: 47.57, Cost: 1705.62, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 9.01, Cost: 8103.40, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 6.75, Cost: 4252.50, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 12.43, Cost: 3940.31, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 6.95, Cost: 2441.25, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 3.70, Cost: 8571.36, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 3901.45, Cost: 8061.92, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 15.50, Cost: 1325.15, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 1483.45, Cost: 22251.75, Comm 0.00
# 2021-06-01, Closing: BBAS3.SA /---/ Rank: 0.0808
# 2021-06-01, Closing: BBDC4.SA /---/ Rank: 0.0978
# 2021-06-01, Closing: CPFE3.SA /---/ Rank: 0.1004
# 2021-06-01, Closing: LAME4.SA /---/ Rank: 0.0925
# 2021-06-01, Rebalancing: AMER3.SA /---/ Rank: 0.1305 /---/ Weight: 0.089
# 2021-06-01, Rebalancing: BRAP4.SA /---/ Rank: 0.1168 /---/ Weight: 0.076
# 2021-06-01, Rebalancing: PETR4.SA /---/ Rank: 0.1069 /---/ Weight: 0.000
# 2021-06-01, Rebalancing: RAIL3.SA /---/ Rank: 0.1346 /---/ Weight: 0.247
# 2021-06-01, Buying: RENT3.SA /---/ Rank: 0.1973 /---/ Weight: 0.396
# 2021-06-01, Buying: VIVT3.SA /---/ Rank: 0.1543 /---/ Weight: 0.000
# 2021-06-01, Buying: GGBR4.SA /---/ Rank: 0.1455 /---/ Weight: 0.099
# 2021-06-01, Buying: GOLL4.SA /---/ Rank: 0.1184 /---/ Weight: 0.092
# 2021-06-01, SELL EXECUTED, Price: 7.35, Cost: 3104.50, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 6.48, Cost: 5770.60, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 6.57, Cost: 13274.76, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 3865.76, Cost: 4030.96, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 43.50, Cost: 12654.60, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 11.95, Cost: 967.97, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 15.09, Cost: 18184.94, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 2.95, Cost: 35978.20, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 12.92, Cost: 9018.16, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 70.88, Cost: 8222.08, Comm 0.00
# 2021-06-01, Closing: AMER3.SA /---/ Rank: 0.0943
# 2021-06-01, Closing: GOLL4.SA /---/ Rank: 0.1030
# 2021-06-01, Rebalancing: BRAP4.SA /---/ Rank: 0.1077 /---/ Weight: 0.000
# 2021-06-01, Rebalancing: GGBR4.SA /---/ Rank: 0.1382 /---/ Weight: 0.022
# 2021-06-01, Rebalancing: RAIL3.SA /---/ Rank: 0.1331 /---/ Weight: 0.239
# 2021-06-01, Rebalancing: RENT3.SA /---/ Rank: 0.1753 /---/ Weight: 0.308
# 2021-06-01, Buying: CYRE3.SA /---/ Rank: nan /---/ Weight: 0.068
# 2021-06-01, Buying: LREN3.SA /---/ Rank: 0.1728 /---/ Weight: 0.212
# 2021-06-01, Buying: GOAU4.SA /---/ Rank: 0.1248 /---/ Weight: 0.000
# 2021-06-01, Buying: PETR4.SA /---/ Rank: 0.1173 /---/ Weight: 0.076
# 2021-06-01, Buying: ITSA4.SA /---/ Rank: 0.1129 /---/ Weight: 0.000
# 2021-06-01, Buying: TIMS3.SA /---/ Rank: 0.1055 /---/ Weight: 0.075
# 2021-06-01, SELL EXECUTED, Price: 39.50, Cost: 10288.74, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 63.88, Cost: 8222.08, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 11.57, Cost: 7521.36, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 13.01, Cost: 7028.48, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 3.04, Cost: 9086.00, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 9.47, Cost: 6051.33, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 2.81, Cost: 18773.61, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 15.63, Cost: 6767.79, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 6295.15, Cost: 6295.15, Comm 0.00
# 2021-06-01, Closing: BRAP4.SA /---/ Rank: 0.0913
# 2021-06-01, Closing: PETR4.SA /---/ Rank: 0.0800
# 2021-06-01, Closing: TIMS3.SA /---/ Rank: 0.0944
# 2021-06-01, Rebalancing: CYRE3.SA /---/ Rank: 0.1445 /---/ Weight: 0.025
# 2021-06-01, Rebalancing: GGBR4.SA /---/ Rank: 0.1006 /---/ Weight: 0.000
# 2021-06-01, Rebalancing: LREN3.SA /---/ Rank: 0.1498 /---/ Weight: 0.119
# 2021-06-01, Rebalancing: RAIL3.SA /---/ Rank: 0.1393 /---/ Weight: 0.167
# 2021-06-01, Rebalancing: RENT3.SA /---/ Rank: 0.1600 /---/ Weight: 0.202
# 2021-06-01, Buying: LAME4.SA /---/ Rank: 0.1360 /---/ Weight: 0.028
# 2021-06-01, Buying: EGIE3.SA /---/ Rank: 0.1287 /---/ Weight: 0.164
# 2021-06-01, Buying: VIVT3.SA /---/ Rank: 0.0966 /---/ Weight: 0.295
# 2021-06-01, SELL EXECUTED, Price: 11.92, Cost: 13.08, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 15.23, Cost: 6767.79, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 6364.25, Cost: 6295.15, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 12.13, Cost: 4138.39, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 12.72, Cost: 1976.76, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 3.14, Cost: 8452.48, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 1696.65, Cost: 7417.25, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 3.01, Cost: 7994.50, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 6.66, Cost: 15964.02, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 13.44, Cost: 28344.96, Comm 0.00
# 2021-06-01, Closing: GGBR4.SA /---/ Rank: 0.0698
# 2021-06-01, Closing: RAIL3.SA /---/ Rank: 0.0268
# 2021-06-01, Rebalancing: CYRE3.SA /---/ Rank: 0.1037 /---/ Weight: 0.000
# 2021-06-01, Rebalancing: EGIE3.SA /---/ Rank: 0.0770 /---/ Weight: 0.000
# 2021-06-01, Rebalancing: LREN3.SA /---/ Rank: 0.1347 /---/ Weight: 0.159
# 2021-06-01, Rebalancing: RENT3.SA /---/ Rank: 0.1548 /---/ Weight: 0.271
# 2021-06-01, Rebalancing: VIVT3.SA /---/ Rank: 0.0794 /---/ Weight: 0.253
# 2021-06-01, Buying: LAME4.SA /---/ Rank: 0.1198 /---/ Weight: 0.083
# 2021-06-01, Buying: GOLL4.SA /---/ Rank: 0.1065 /---/ Weight: 0.105
# 2021-06-01, Buying: SBSP3.SA /---/ Rank: 0.1054 /---/ Weight: 0.075
# 2021-06-01, Buying: TIMS3.SA /---/ Rank: 0.0987 /---/ Weight: 0.054
# 2021-06-01, SELL EXECUTED, Price: 11.42, Cost: 12.92, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 169.47, Cost: 14834.50, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 12.26, Cost: 1912.94, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 6.18, Cost: 15964.02, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 3.08, Cost: 1573.88, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 3.16, Cost: 1538.92, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 13.27, Cost: 7620.48, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 4281.60, Cost: 4281.60, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 68.78, Cost: 8528.72, Comm 0.00
# 2021-06-01, Closing: GOLL4.SA /---/ Rank: 0.0879
# 2021-06-01, Rebalancing: LAME4.SA /---/ Rank: 0.1380 /---/ Weight: 0.135
# 2021-06-01, Rebalancing: LREN3.SA /---/ Rank: 0.1401 /---/ Weight: 0.117
# 2021-06-01, Rebalancing: RENT3.SA /---/ Rank: 0.1558 /---/ Weight: 0.233
# 2021-06-01, Rebalancing: VIVT3.SA /---/ Rank: 0.1052 /---/ Weight: 0.251
# 2021-06-01, Buying: CYRE3.SA /---/ Rank: 0.1244 /---/ Weight: 0.014
# 2021-06-01, Buying: SBSP3.SA /---/ Rank: 0.1197 /---/ Weight: 0.144
# 2021-06-01, Buying: CSNA3.SA /---/ Rank: 0.1120 /---/ Weight: 0.010
# 2021-06-01, Buying: TIMS3.SA /---/ Rank: 0.1065 /---/ Weight: 0.096
# 2021-06-01, Buying: GOAU4.SA /---/ Rank: 0.1045 /---/ Weight: 0.000
# 2021-06-01, SELL EXECUTED, Price: 61.85, Cost: 8528.72, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 4679.36, Cost: 4679.36, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 3.24, Cost: 3093.16, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 3.64, Cost: 4586.60, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 13.48, Cost: 404.40, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 13.93, Cost: 1184.05, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 7104.15, Cost: 7104.15, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 6.12, Cost: 850.68, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 7653.99, Cost: 7653.99, Comm 0.00
# 2021-06-01, Closing: CSNA3.SA /---/ Rank: 0.0839
# 2021-06-01, Closing: CYRE3.SA /---/ Rank: 0.0804
# 2021-06-01, Closing: VIVT3.SA /---/ Rank: 0.0793
# 2021-06-01, Rebalancing: LAME4.SA /---/ Rank: 0.1097 /---/ Weight: 0.146
# 2021-06-01, Rebalancing: LREN3.SA /---/ Rank: 0.1167 /---/ Weight: 0.090
# 2021-06-01, Rebalancing: RENT3.SA /---/ Rank: 0.1308 /---/ Weight: 0.190
# 2021-06-01, Rebalancing: SBSP3.SA /---/ Rank: 0.1283 /---/ Weight: 0.261
# 2021-06-01, Rebalancing: TIMS3.SA /---/ Rank: 0.1198 /---/ Weight: 0.172
# 2021-06-01, Buying: GGBR4.SA /---/ Rank: 0.1012 /---/ Weight: 0.000
# 2021-06-01, Buying: CCRO3.SA /---/ Rank: 0.0983 /---/ Weight: 0.064
# 2021-06-01, Buying: AMER3.SA /---/ Rank: 0.0967 /---/ Weight: 0.077
# 2021-06-01, Buying: BRAP4.SA /---/ Rank: 0.0941 /---/ Weight: 0.000
# 2021-06-01, Buying: GOAU4.SA /---/ Rank: 0.0907 /---/ Weight: 0.000
# 2021-06-01, SELL EXECUTED, Price: 5.68, Cost: 850.68, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 13.51, Cost: 1184.05, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 14.08, Cost: 21128.88, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 3.44, Cost: 2211.84, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 3.79, Cost: 2828.45, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 6902.91, Cost: 13805.82, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 3.82, Cost: 5718.54, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 66.05, Cost: 6737.10, Comm 0.00
# 2021-06-01, Closing: AMER3.SA /---/ Rank: 0.0732
# 2021-06-01, Rebalancing: CCRO3.SA /---/ Rank: 0.0884 /---/ Weight: 0.041
# 2021-06-01, Rebalancing: LAME4.SA /---/ Rank: 0.1034 /---/ Weight: 0.054
# 2021-06-01, Rebalancing: LREN3.SA /---/ Rank: 0.1175 /---/ Weight: 0.101
# 2021-06-01, Rebalancing: RENT3.SA /---/ Rank: 0.1350 /---/ Weight: 0.173
# 2021-06-01, Rebalancing: SBSP3.SA /---/ Rank: 0.1207 /---/ Weight: 0.158
# 2021-06-01, Rebalancing: TIMS3.SA /---/ Rank: 0.1013 /---/ Weight: 0.093
# 2021-06-01, Buying: BRAP4.SA /---/ Rank: 0.1153 /---/ Weight: 0.073
# 2021-06-01, Buying: VIVT3.SA /---/ Rank: 0.1053 /---/ Weight: 0.306
# 2021-06-01, Buying: PETR4.SA /---/ Rank: 0.0854 /---/ Weight: 0.000
# 2021-06-01, Buying: ITSA4.SA /---/ Rank: 0.0848 /---/ Weight: 0.000
# 2021-06-01, SELL EXECUTED, Price: 71.00, Cost: 6737.10, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 4.03, Cost: 1837.42, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 5895.03, Cost: 4480.48, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 3.84, Cost: 1071.36, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 4.36, Cost: 1509.10, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 8003.78, Cost: 6969.99, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 16.50, Cost: 7194.00, Comm 0.00
# 2021-06-01, Order Margin. Price: 16.19
# 2021-06-01, Closing: CCRO3.SA /---/ Rank: 0.0575
# 2021-06-01, Closing: TIMS3.SA /---/ Rank: 0.0630
# 2021-06-01, Rebalancing: BRAP4.SA /---/ Rank: 0.1106 /---/ Weight: 0.245
# 2021-06-01, Rebalancing: LAME4.SA /---/ Rank: 0.0808 /---/ Weight: 0.037
# 2021-06-01, Rebalancing: LREN3.SA /---/ Rank: 0.0810 /---/ Weight: 0.027
# 2021-06-01, Rebalancing: RENT3.SA /---/ Rank: 0.1003 /---/ Weight: 0.185
# 2021-06-01, Rebalancing: SBSP3.SA /---/ Rank: 0.0799 /---/ Weight: 0.107
# 2021-06-01, Buying: VIVT3.SA /---/ Rank: 0.1035 /---/ Weight: 0.399
# 2021-06-01, Buying: ITSA4.SA /---/ Rank: 0.0814 /---/ Weight: 0.000
# 2021-06-01, Buying: USIM5.SA /---/ Rank: 0.0725 /---/ Weight: 0.000
# 2021-06-01, Buying: GOAU4.SA /---/ Rank: 0.0675 /---/ Weight: 0.000
# 2021-06-01, Buying: CSNA3.SA /---/ Rank: 0.0668 /---/ Weight: 0.000
# 2021-06-01, SELL EXECUTED, Price: 3.76, Cost: 3881.12, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 8828.57, Cost: 7653.99, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 18.38, Cost: 15733.28, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 3.58, Cost: 5434.06, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 4.38, Cost: 1020.54, Comm 0.00
# 2021-06-01, Order Margin. Price: 16.66
# 2021-06-01, Rebalancing: BRAP4.SA /---/ Rank: 0.1129 /---/ Weight: 0.352
# 2021-06-01, Rebalancing: LAME4.SA /---/ Rank: 0.0672 /---/ Weight: 0.000
# 2021-06-01, Rebalancing: LREN3.SA /---/ Rank: 0.0733 /---/ Weight: 0.022
# 2021-06-01, Rebalancing: RENT3.SA /---/ Rank: 0.0712 /---/ Weight: 0.085
# 2021-06-01, Rebalancing: SBSP3.SA /---/ Rank: 0.0979 /---/ Weight: 0.319
# 2021-06-01, Buying: VIVT3.SA /---/ Rank: 0.0855 /---/ Weight: 0.218
# 2021-06-01, Buying: VALE3.SA /---/ Rank: 0.0789 /---/ Weight: 0.000
# 2021-06-01, Buying: CCRO3.SA /---/ Rank: 0.0667 /---/ Weight: 0.004
# 2021-06-01, Buying: USIM5.SA /---/ Rank: 0.0572 /---/ Weight: 0.000
# 2021-06-01, BUY EXECUTED, Price: 18.52, Cost: 9371.12, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 5638.13, Cost: 4480.48, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 3.45, Cost: 454.31, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 3.77, Cost: 5955.92, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 8049.70, Cost: 8049.70, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 15.68, Cost: 20791.68, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 3.60, Cost: 360.00, Comm 0.00
# 2021-06-01, Closing: LREN3.SA /---/ Rank: 0.0476
# 2021-06-01, Rebalancing: BRAP4.SA /---/ Rank: 0.1216 /---/ Weight: 0.291
# 2021-06-01, Rebalancing: CCRO3.SA /---/ Rank: 0.0634 /---/ Weight: 0.000
# 2021-06-01, Rebalancing: RENT3.SA /---/ Rank: 0.0903 /---/ Weight: 0.172
# 2021-06-01, Rebalancing: SBSP3.SA /---/ Rank: 0.0935 /---/ Weight: 0.151
# 2021-06-01, Rebalancing: VIVT3.SA /---/ Rank: 0.0671 /---/ Weight: 0.000
# 2021-06-01, Buying: HGTX3.SA /---/ Rank: 0.1734 /---/ Weight: 0.304
# 2021-06-01, Buying: TOTS3.SA /---/ Rank: 0.0909 /---/ Weight: 0.083
# 2021-06-01, Buying: LAME4.SA /---/ Rank: 0.0678 /---/ Weight: 0.000
# 2021-06-01, SELL EXECUTED, Price: 3.32, Cost: 1773.00, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 20.01, Cost: 7005.77, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 3.78, Cost: 360.00, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 4.21, Cost: 7451.70, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 7347.92, Cost: 7329.89, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 15.69, Cost: 20791.68, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 2.01, Cost: 31126.86, Comm 0.00
# 2021-06-01, Order Margin. Price: 2.77
# 2021-06-01, Rebalancing: BRAP4.SA /---/ Rank: 0.1272 /---/ Weight: 0.172
# 2021-06-01, Rebalancing: HGTX3.SA /---/ Rank: 0.1866 /---/ Weight: 0.289
# 2021-06-01, Rebalancing: RENT3.SA /---/ Rank: 0.0857 /---/ Weight: 0.085
# 2021-06-01, Rebalancing: SBSP3.SA /---/ Rank: 0.0733 /---/ Weight: 0.000
# 2021-06-01, Buying: CCRO3.SA /---/ Rank: 0.1016 /---/ Weight: 0.084
# 2021-06-01, Buying: VIVT3.SA /---/ Rank: 0.0949 /---/ Weight: 0.316
# 2021-06-01, Buying: TOTS3.SA /---/ Rank: 0.0772 /---/ Weight: 0.029
# 2021-06-01, Buying: LAME4.SA /---/ Rank: 0.0761 /---/ Weight: 0.026
# 2021-06-01, SELL EXECUTED, Price: 22.10, Cost: 11388.87, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 2.00, Cost: 2170.80, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 4.25, Cost: 6853.76, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 7401.67, Cost: 14659.79, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 4.36, Cost: 8454.04, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 18.88, Cost: 31529.60, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 2.96, Cost: 2838.64, Comm 0.00
# 2021-06-01, Rebalancing: BRAP4.SA /---/ Rank: 0.1305 /---/ Weight: 0.127
# 2021-06-01, Rebalancing: CCRO3.SA /---/ Rank: 0.1109 /---/ Weight: 0.119
# 2021-06-01, Rebalancing: HGTX3.SA /---/ Rank: 0.1473 /---/ Weight: 0.217
# 2021-06-01, Rebalancing: TOTS3.SA /---/ Rank: 0.1016 /---/ Weight: 0.091
# 2021-06-01, Rebalancing: VIVT3.SA /---/ Rank: 0.1287 /---/ Weight: 0.313
# 2021-06-01, Buying: LAME4.SA /---/ Rank: 0.1104 /---/ Weight: 0.100
# 2021-06-01, Buying: AMER3.SA /---/ Rank: 0.0916 /---/ Weight: 0.033
# 2021-06-01, SELL EXECUTED, Price: 24.00, Cost: 3466.96, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 4.45, Cost: 4650.25, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 2.43, Cost: 9358.56, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 3.31, Cost: 6831.84, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 19.78, Cost: 1206.58, Comm 0.00
# 2021-06-01, Order Margin. Price: 6894.22
# 2021-06-01, BUY EXECUTED, Price: 82.08, Cost: 3611.52, Comm 0.00
# 2021-06-01, Closing: AMER3.SA /---/ Rank: 0.1016
# 2021-06-01, Closing: RENT3.SA /---/ Rank: 0.1015
# 2021-06-01, Rebalancing: BRAP4.SA /---/ Rank: 0.1629 /---/ Weight: 0.081
# 2021-06-01, Rebalancing: CCRO3.SA /---/ Rank: 0.1434 /---/ Weight: 0.118
# 2021-06-01, Rebalancing: HGTX3.SA /---/ Rank: 0.1554 /---/ Weight: 0.142
# 2021-06-01, Rebalancing: TOTS3.SA /---/ Rank: 0.1289 /---/ Weight: 0.095
# 2021-06-01, Rebalancing: VIVT3.SA /---/ Rank: 0.1513 /---/ Weight: 0.240
# 2021-06-01, Buying: LAME4.SA /---/ Rank: 0.1496 /---/ Weight: 0.150
# 2021-06-01, Buying: CPFE3.SA /---/ Rank: 0.1240 /---/ Weight: 0.173
# 2021-06-01, SELL EXECUTED, Price: 82.50, Cost: 3611.52, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 4.69, Cost: 7175.03, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 24.69, Cost: 3772.34, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 4.96, Cost: 1335.02, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 2.30, Cost: 5756.64, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 3.17, Cost: 1144.37, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 20.49, Cost: 8075.30, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 7422.34, Cost: 14844.68, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 10.06, Cost: 19325.26, Comm 0.00
# 2021-06-01, Closing: CPFE3.SA /---/ Rank: 0.0977
# 2021-06-01, Closing: TOTS3.SA /---/ Rank: 0.1123
# 2021-06-01, Rebalancing: BRAP4.SA /---/ Rank: 0.1735 /---/ Weight: 0.226
# 2021-06-01, Rebalancing: CCRO3.SA /---/ Rank: 0.1355 /---/ Weight: 0.114
# 2021-06-01, Rebalancing: HGTX3.SA /---/ Rank: 0.1290 /---/ Weight: 0.147
# 2021-06-01, Rebalancing: LAME4.SA /---/ Rank: 0.1452 /---/ Weight: 0.182
# 2021-06-01, Rebalancing: VIVT3.SA /---/ Rank: 0.1297 /---/ Weight: 0.180
# 2021-06-01, Buying: SBSP3.SA /---/ Rank: 0.1590 /---/ Weight: 0.000
# 2021-06-01, Buying: TIMS3.SA /---/ Rank: 0.1551 /---/ Weight: 0.000
# 2021-06-01, Buying: CMIG4.SA /---/ Rank: 0.1527 /---/ Weight: 0.000
# 2021-06-01, Buying: BBAS3.SA /---/ Rank: 0.1440 /---/ Weight: 0.150
# 2021-06-01, Buying: VALE3.SA /---/ Rank: 0.1365 /---/ Weight: 0.000
# 2021-06-01, SELL EXECUTED, Price: 9.27, Cost: 19325.26, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 3.00, Cost: 10814.85, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 26.31, Cost: 14759.91, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 4.61, Cost: 124.47, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 2.03, Cost: 1924.44, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 20.50, Cost: 6581.28, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 13.73, Cost: 16270.05, Comm 0.00
# 2021-06-01, Closing: CCRO3.SA /---/ Rank: 0.1091
# 2021-06-01, Closing: VIVT3.SA /---/ Rank: 0.1002
# 2021-06-01, Rebalancing: BBAS3.SA /---/ Rank: 0.1244 /---/ Weight: 0.287
# 2021-06-01, Rebalancing: BRAP4.SA /---/ Rank: 0.1508 /---/ Weight: 0.370
# 2021-06-01, Rebalancing: HGTX3.SA /---/ Rank: 0.1259 /---/ Weight: 0.213
# 2021-06-01, Rebalancing: LAME4.SA /---/ Rank: 0.1597 /---/ Weight: 0.000
# 2021-06-01, Buying: VALE3.SA /---/ Rank: 0.1379 /---/ Weight: 0.130
# 2021-06-01, SELL EXECUTED, Price: 4.80, Cost: 11893.74, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 21.17, Cost: 18079.60, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 13.10, Cost: 11056.40, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 26.80, Cost: 8870.80, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 1.91, Cost: 5141.72, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 7.99, Cost: 14844.68, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 28.72, Cost: 12033.68, Comm 0.00
# 2021-06-01, Closing: HGTX3.SA /---/ Rank: 0.1223
# 2021-06-01, Rebalancing: BBAS3.SA /---/ Rank: 0.1403 /---/ Weight: 0.113
# 2021-06-01, Rebalancing: BRAP4.SA /---/ Rank: 0.2074 /---/ Weight: 0.626
# 2021-06-01, Rebalancing: VALE3.SA /---/ Rank: 0.1931 /---/ Weight: 0.261
# 2021-06-01, Buying: LAME4.SA /---/ Rank: 0.1604 /---/ Weight: 0.000
# 2021-06-01, Buying: SBSP3.SA /---/ Rank: 0.1573 /---/ Weight: 0.000
# 2021-06-01, Buying: TIMS3.SA /---/ Rank: 0.1555 /---/ Weight: 0.000
# 2021-06-01, Buying: ELET3.SA /---/ Rank: 0.1536 /---/ Weight: 0.000
# 2021-06-01, Buying: CPLE6.SA /---/ Rank: 0.1536 /---/ Weight: 0.000
# 2021-06-01, Buying: CMIG4.SA /---/ Rank: 0.1531 /---/ Weight: 0.000
# 2021-06-01, SELL EXECUTED, Price: 2.18, Cost: 20907.02, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 14.43, Cost: 15313.05, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 35.95, Cost: 25560.45, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 38.22, Cost: 13568.10, Comm 0.00
# 2021-06-01, Rebalancing: BBAS3.SA /---/ Rank: 0.1350 /---/ Weight: 0.135
# 2021-06-01, Rebalancing: BRAP4.SA /---/ Rank: 0.1844 /---/ Weight: 0.646
# 2021-06-01, Rebalancing: VALE3.SA /---/ Rank: 0.1699 /---/ Weight: 0.058
# 2021-06-01, Buying: LAME4.SA /---/ Rank: 0.1612 /---/ Weight: 0.000
# 2021-06-01, Buying: SBSP3.SA /---/ Rank: 0.1565 /---/ Weight: 0.000
# 2021-06-01, Buying: TIMS3.SA /---/ Rank: 0.1553 /---/ Weight: 0.000
# 2021-06-01, Buying: ELET3.SA /---/ Rank: 0.1529 /---/ Weight: 0.000
# 2021-06-01, Buying: CPLE6.SA /---/ Rank: 0.1528 /---/ Weight: 0.000
# 2021-06-01, Buying: CMIG4.SA /---/ Rank: 0.1522 /---/ Weight: 0.000
# 2021-06-01, Buying: PETR4.SA /---/ Rank: 0.1358 /---/ Weight: 0.161
# 2021-06-01, Order Margin. Price: 14.18
# 2021-06-01, Order Margin. Price: 34.39
# 2021-06-01, SELL EXECUTED, Price: 36.94, Cost: 19978.65, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 25.73, Cost: 17342.02, Comm 0.00
# 2021-06-01, Closing: BBAS3.SA /---/ Rank: 0.1108
# 2021-06-01, Closing: PETR4.SA /---/ Rank: 0.1051
# 2021-06-01, Rebalancing: BRAP4.SA /---/ Rank: 0.1535 /---/ Weight: 0.389
# 2021-06-01, Rebalancing: VALE3.SA /---/ Rank: 0.1403 /---/ Weight: 0.013
# 2021-06-01, Buying: LAME4.SA /---/ Rank: 0.1589 /---/ Weight: 0.000
# 2021-06-01, Buying: SBSP3.SA /---/ Rank: 0.1564 /---/ Weight: 0.000
# 2021-06-01, Buying: ELET3.SA /---/ Rank: 0.1529 /---/ Weight: 0.000
# 2021-06-01, Buying: CPLE6.SA /---/ Rank: 0.1528 /---/ Weight: 0.000
# 2021-06-01, Buying: CMIG4.SA /---/ Rank: 0.1519 /---/ Weight: 0.000
# 2021-06-01, Buying: TIMS3.SA /---/ Rank: 0.1513 /---/ Weight: 0.000
# 2021-06-01, Buying: HGTX3.SA /---/ Rank: 0.1428 /---/ Weight: 0.341
# 2021-06-01, Buying: CSNA3.SA /---/ Rank: 0.1280 /---/ Weight: 0.256
# 2021-06-01, SELL EXECUTED, Price: 13.73, Cost: 12013.40, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 26.71, Cost: 17342.02, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 32.63, Cost: 20005.03, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 36.12, Cost: 4333.12, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 2.40, Cost: 36410.40, Comm 0.00
# 2021-06-01, Order Margin. Price: 12.37
# 2021-06-01, Closing: BRAP4.SA /---/ Rank: 0.1158
# 2021-06-01, Rebalancing: HGTX3.SA /---/ Rank: 0.1298 /---/ Weight: 0.241
# 2021-06-01, Rebalancing: VALE3.SA /---/ Rank: 0.1160 /---/ Weight: 0.000
# 2021-06-01, Buying: CSNA3.SA /---/ Rank: 0.1704 /---/ Weight: 0.579
# 2021-06-01, Buying: LAME4.SA /---/ Rank: 0.1567 /---/ Weight: 0.000
# 2021-06-01, Buying: SBSP3.SA /---/ Rank: 0.1558 /---/ Weight: 0.000
# 2021-06-01, Buying: CPLE6.SA /---/ Rank: 0.1524 /---/ Weight: 0.000
# 2021-06-01, Buying: ELET3.SA /---/ Rank: 0.1516 /---/ Weight: 0.000
# 2021-06-01, Buying: CMIG4.SA /---/ Rank: 0.1501 /---/ Weight: 0.000
# 2021-06-01, Buying: TIMS3.SA /---/ Rank: 0.1499 /---/ Weight: 0.000
# 2021-06-01, Buying: PETR4.SA /---/ Rank: 0.1286 /---/ Weight: 0.180
# 2021-06-01, SELL EXECUTED, Price: 30.34, Cost: 35850.60, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 2.07, Cost: 8644.80, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 34.13, Cost: 1290.01, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 14.15, Cost: 56302.85, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 31.86, Cost: 17427.42, Comm 0.00
# 2021-06-01, Rebalancing: CSNA3.SA /---/ Rank: 0.1609 /---/ Weight: 0.797
# 2021-06-01, Rebalancing: HGTX3.SA /---/ Rank: 0.0976 /---/ Weight: 0.203
# 2021-06-01, Rebalancing: PETR4.SA /---/ Rank: 0.1081 /---/ Weight: 0.000
# 2021-06-01, Buying: LAME4.SA /---/ Rank: 0.1549 /---/ Weight: 0.000
# 2021-06-01, Buying: CPLE6.SA /---/ Rank: 0.1516 /---/ Weight: 0.000
# 2021-06-01, Buying: TIMS3.SA /---/ Rank: 0.1507 /---/ Weight: 0.000
# 2021-06-01, Buying: VALE3.SA /---/ Rank: 0.0867 /---/ Weight: 0.000
# 2021-06-01, Order Margin. Price: 16.07
# 2021-06-01, SELL EXECUTED, Price: 1.94, Cost: 1812.00, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 29.13, Cost: 17395.56, Comm 0.00
# 2021-06-01, Closing: HGTX3.SA /---/ Rank: 0.0573
# 2021-06-01, Rebalancing: CSNA3.SA /---/ Rank: 0.1572 /---/ Weight: 0.882
# 2021-06-01, Rebalancing: PETR4.SA /---/ Rank: 0.1121 /---/ Weight: 0.118
# 2021-06-01, Buying: LAME4.SA /---/ Rank: 0.1561 /---/ Weight: 0.000
# 2021-06-01, Buying: SBSP3.SA /---/ Rank: 0.1547 /---/ Weight: 0.000
# 2021-06-01, Buying: ELET3.SA /---/ Rank: 0.1528 /---/ Weight: 0.000
# 2021-06-01, Buying: CPLE6.SA /---/ Rank: 0.1524 /---/ Weight: 0.000
# 2021-06-01, Buying: TIMS3.SA /---/ Rank: 0.1517 /---/ Weight: 0.000
# 2021-06-01, Buying: CMIG4.SA /---/ Rank: 0.1503 /---/ Weight: 0.000
# 2021-06-01, SELL EXECUTED, Price: 1.91, Cost: 25953.60, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 17.85, Cost: 25275.60, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 29.45, Cost: 12722.40, Comm 0.00
# 2021-06-01, Rebalancing: CSNA3.SA /---/ Rank: 0.1488 /---/ Weight: 0.665
# 2021-06-01, Rebalancing: PETR4.SA /---/ Rank: 0.1062 /---/ Weight: 0.116
# 2021-06-01, Buying: LAME4.SA /---/ Rank: 0.1552 /---/ Weight: 0.000
# 2021-06-01, Buying: SBSP3.SA /---/ Rank: 0.1547 /---/ Weight: 0.000
# 2021-06-01, Buying: ELET3.SA /---/ Rank: 0.1540 /---/ Weight: 0.000
# 2021-06-01, Buying: CPLE6.SA /---/ Rank: 0.1532 /---/ Weight: 0.000
# 2021-06-01, Buying: TIMS3.SA /---/ Rank: 0.1506 /---/ Weight: 0.000
# 2021-06-01, Buying: CMIG4.SA /---/ Rank: 0.1501 /---/ Weight: 0.000
# 2021-06-01, Buying: WEGE3.SA /---/ Rank: 0.1109 /---/ Weight: 0.219
# 2021-06-01, SELL EXECUTED, Price: 17.90, Cost: 20262.30, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 28.02, Cost: 504.36, Comm 0.00
# 2021-06-01, Order Margin. Price: 2.23
# 2021-06-01, Rebalancing: CSNA3.SA /---/ Rank: 0.1520 /---/ Weight: 0.603
# 2021-06-01, Rebalancing: PETR4.SA /---/ Rank: 0.1028 /---/ Weight: 0.135
# 2021-06-01, Buying: RADL3.SA /---/ Rank: nan /---/ Weight: 0.262
# 2021-06-01, Buying: GOAU4.SA /---/ Rank: 0.0982 /---/ Weight: 0.000
# 2021-06-01, SELL EXECUTED, Price: 20.21, Cost: 6880.11, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 31.94, Cost: 1724.76, Comm 0.00
# 2021-06-01, Order Margin. Price: 0.72
# 2021-06-01, Rebalancing: CSNA3.SA /---/ Rank: 0.1480 /---/ Weight: 0.420
# 2021-06-01, Rebalancing: PETR4.SA /---/ Rank: 0.1314 /---/ Weight: 0.286
# 2021-06-01, Buying: TIMS3.SA /---/ Rank: 0.1493 /---/ Weight: 0.000
# 2021-06-01, Buying: RADL3.SA /---/ Rank: 0.1391 /---/ Weight: 0.248
# 2021-06-01, Buying: GGBR4.SA /---/ Rank: 0.1210 /---/ Weight: 0.045
# 2021-06-01, SELL EXECUTED, Price: 22.51, Cost: 17222.96, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 36.74, Cost: 18516.96, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 0.86, Cost: 32221.62, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 33.24, Cost: 5817.00, Comm 0.00
# 2021-06-01, Closing: RADL3.SA /---/ Rank: 0.0023
# 2021-06-01, Rebalancing: CSNA3.SA /---/ Rank: 0.1300 /---/ Weight: 0.659
# 2021-06-01, Rebalancing: GGBR4.SA /---/ Rank: 0.0920 /---/ Weight: 0.000
# 2021-06-01, Rebalancing: PETR4.SA /---/ Rank: 0.1086 /---/ Weight: 0.341
# 2021-06-01, Buying: ELET3.SA /---/ Rank: 0.1535 /---/ Weight: 0.000
# 2021-06-01, Buying: CPLE6.SA /---/ Rank: 0.1526 /---/ Weight: 0.000
# 2021-06-01, Buying: LAME4.SA /---/ Rank: 0.1517 /---/ Weight: 0.000
# 2021-06-01, Buying: TIMS3.SA /---/ Rank: 0.1473 /---/ Weight: 0.000
# 2021-06-01, SELL EXECUTED, Price: 0.85, Cost: 32221.62, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 19.35, Cost: 31734.00, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 32.06, Cost: 5817.00, Comm 0.00
# 2021-06-01, Order Margin. Price: 34.07
# 2021-06-01, Rebalancing: CSNA3.SA /---/ Rank: 0.0963 /---/ Weight: 0.818
# 2021-06-01, Rebalancing: PETR4.SA /---/ Rank: 0.0539 /---/ Weight: 0.000
# 2021-06-01, Buying: GOAU4.SA /---/ Rank: 0.0620 /---/ Weight: 0.000
# 2021-06-01, Buying: TAEE11.SA /---/ Rank: 0.0250 /---/ Weight: 0.182
# 2021-06-01, Order Margin. Price: 16.64
# 2021-06-01, SELL EXECUTED, Price: 25.51, Cost: 33467.14, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 2.94, Cost: 17787.00, Comm 0.00
# 2021-06-01, Closing: TAEE11.SA /---/ Rank: 0.0168
# 2021-06-01, Rebalancing: CSNA3.SA /---/ Rank: 0.0905 /---/ Weight: 0.964
# 2021-06-01, Rebalancing: PETR4.SA /---/ Rank: 0.0657 /---/ Weight: 0.036
# 2021-06-01, Buying: GOAU4.SA /---/ Rank: 0.0646 /---/ Weight: 0.000
# 2021-06-01, Buying: GGBR4.SA /---/ Rank: 0.0637 /---/ Weight: 0.000
# 2021-06-01, Buying: BRFS3.SA /---/ Rank: 0.0426 /---/ Weight: 0.000
# 2021-06-01, Buying: MRVE3.SA /---/ Rank: 0.0264 /---/ Weight: 0.000
# 2021-06-01, Buying: CYRE3.SA /---/ Rank: 0.0242 /---/ Weight: 0.000
# 2021-06-01, Buying: EGIE3.SA /---/ Rank: 0.0229 /---/ Weight: 0.000
# 2021-06-01, SELL EXECUTED, Price: 2.75, Cost: 17787.00, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 15.78, Cost: 26242.14, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 24.63, Cost: 3275.79, Comm 0.00
# 2021-06-01, Rebalancing: CSNA3.SA /---/ Rank: 0.0308 /---/ Weight: 0.000
# 2021-06-01, Rebalancing: PETR4.SA /---/ Rank: 0.0493 /---/ Weight: 0.421
# 2021-06-01, Buying: CPFE3.SA /---/ Rank: 0.0383 /---/ Weight: 0.579
# 2021-06-01, Buying: ELET3.SA /---/ Rank: 0.0297 /---/ Weight: 0.000
# 2021-06-01, Buying: GOAU4.SA /---/ Rank: 0.0259 /---/ Weight: 0.000
# 2021-06-01, Buying: EGIE3.SA /---/ Rank: 0.0216 /---/ Weight: 0.000
# 2021-06-01, Buying: NTCO3.SA /---/ Rank: 0.0139 /---/ Weight: 0.000
# 2021-06-01, SELL EXECUTED, Price: 10.85, Cost: 95189.22, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 25.10, Cost: 24748.60, Comm 0.00
# 2021-06-01, Order Margin. Price: 10.58
# 2021-06-01, Rebalancing: PETR4.SA /---/ Rank: -0.0179 /---/ Weight: 0.000
# 2021-06-01, Buying: ELET3.SA /---/ Rank: 0.0162 /---/ Weight: 1.000
# 2021-06-01, Buying: CPFE3.SA /---/ Rank: 0.0086 /---/ Weight: 0.000
# 2021-06-01, Buying: CPLE6.SA /---/ Rank: 0.0010 /---/ Weight: 0.000
# 2021-06-01, Buying: CMIG4.SA /---/ Rank: -0.0002 /---/ Weight: 0.000
# 2021-06-01, Buying: NTCO3.SA /---/ Rank: -0.0048 /---/ Weight: 0.000
# 2021-06-01, Buying: ENBR3.SA /---/ Rank: -0.0148 /---/ Weight: 0.000
# 2021-06-01, SELL EXECUTED, Price: 17.60, Cost: 28057.59, Comm 0.00
# 2021-06-01, Order Margin. Price: 11.46
# 2021-06-01, Buying: NTCO3.SA /---/ Rank: 0.0312 /---/ Weight: 1.000
# 2021-06-01, Buying: ELET3.SA /---/ Rank: 0.0185 /---/ Weight: 0.000
# 2021-06-01, Buying: EGIE3.SA /---/ Rank: 0.0072 /---/ Weight: 0.000
# 2021-06-01, Buying: JBSS3.SA /---/ Rank: -0.0002 /---/ Weight: 0.000
# 2021-06-01, Order Margin. Price: 8.9
# 2021-06-01, Buying: ELET3.SA /---/ Rank: 0.0326 /---/ Weight: 0.502
# 2021-06-01, Buying: NTCO3.SA /---/ Rank: 0.0279 /---/ Weight: 0.498
# 2021-06-01, Buying: JBSS3.SA /---/ Rank: 0.0156 /---/ Weight: 0.000
# 2021-06-01, Buying: ENBR3.SA /---/ Rank: 0.0088 /---/ Weight: 0.000
# 2021-06-01, Buying: CMIG4.SA /---/ Rank: 0.0072 /---/ Weight: 0.000
# 2021-06-01, Buying: CCRO3.SA /---/ Rank: 0.0039 /---/ Weight: 0.000
# 2021-06-01, Buying: VIVT3.SA /---/ Rank: -0.0018 /---/ Weight: 0.000
# 2021-06-01, BUY EXECUTED, Price: 11.94, Cost: 29408.22, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 8.37, Cost: 28750.95, Comm 0.00
# 2021-06-01, Rebalancing: ELET3.SA /---/ Rank: 0.0395 /---/ Weight: 0.044
# 2021-06-01, Rebalancing: NTCO3.SA /---/ Rank: 0.0517 /---/ Weight: 0.956
# 2021-06-01, Buying: CMIG4.SA /---/ Rank: 0.0255 /---/ Weight: 0.000
# 2021-06-01, Buying: CPFE3.SA /---/ Rank: 0.0255 /---/ Weight: 0.000
# 2021-06-01, Buying: EGIE3.SA /---/ Rank: 0.0116 /---/ Weight: 0.000
# 2021-06-01, SELL EXECUTED, Price: 11.32, Cost: 26757.54, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 8.20, Cost: 25715.20, Comm 0.00
# 2021-06-01, Rebalancing: ELET3.SA /---/ Rank: 0.0290 /---/ Weight: 0.000
# 2021-06-01, Rebalancing: NTCO3.SA /---/ Rank: 0.0632 /---/ Weight: 1.000
# 2021-06-01, Buying: CPFE3.SA /---/ Rank: 0.0153 /---/ Weight: 0.000
# 2021-06-01, SELL EXECUTED, Price: 11.24, Cost: 2650.68, Comm 0.00
# 2021-06-01, Order Margin. Price: 8.94
# 2021-06-01, Rebalancing: NTCO3.SA /---/ Rank: 0.0478 /---/ Weight: 0.728
# 2021-06-01, Buying: CMIG4.SA /---/ Rank: 0.0332 /---/ Weight: 0.102
# 2021-06-01, Buying: SULA11.SA /---/ Rank: 0.0316 /---/ Weight: 0.000
# 2021-06-01, Buying: VIVT3.SA /---/ Rank: 0.0279 /---/ Weight: 0.170
# 2021-06-01, Buying: ENBR3.SA /---/ Rank: 0.0260 /---/ Weight: 0.000
# 2021-06-01, Buying: ELET3.SA /---/ Rank: 0.0136 /---/ Weight: 0.000
# 2021-06-01, SELL EXECUTED, Price: 9.74, Cost: 13129.57, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 7.21, Cost: 6842.29, Comm 0.00
# 2021-06-01, Order Margin. Price: 16.7
# 2021-06-01, Closing: CMIG4.SA /---/ Rank: -0.0126
# 2021-06-01, Rebalancing: NTCO3.SA /---/ Rank: 0.0645 /---/ Weight: 0.506
# 2021-06-01, Buying: TAEE11.SA /---/ Rank: 0.0430 /---/ Weight: 0.186
# 2021-06-01, Buying: VIVT3.SA /---/ Rank: 0.0398 /---/ Weight: 0.205
# 2021-06-01, Buying: TOTS3.SA /---/ Rank: 0.0306 /---/ Weight: 0.065
# 2021-06-01, Buying: HYPE3.SA /---/ Rank: 0.0303 /---/ Weight: 0.000
# 2021-06-01, Buying: SULA11.SA /---/ Rank: 0.0295 /---/ Weight: 0.000
# 2021-06-01, Buying: RADL3.SA /---/ Rank: 0.0274 /---/ Weight: 0.021
# 2021-06-01, Buying: HGTX3.SA /---/ Rank: 0.0222 /---/ Weight: 0.018
# 2021-06-01, SELL EXECUTED, Price: 5.40, Cost: 6842.29, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 11.56, Cost: 14505.52, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 3.77, Cost: 13817.05, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 17.13, Cost: 15091.53, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 3.27, Cost: 4819.98, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 0.79, Cost: 1568.15, Comm 0.00
# 2021-06-01, Order Margin. Price: 1.98
# 2021-06-01, Rebalancing: NTCO3.SA /---/ Rank: 0.0549 /---/ Weight: 0.346
# 2021-06-01, Rebalancing: RADL3.SA /---/ Rank: 0.0393 /---/ Weight: 0.116
# 2021-06-01, Rebalancing: TAEE11.SA /---/ Rank: 0.0501 /---/ Weight: 0.185
# 2021-06-01, Rebalancing: TOTS3.SA /---/ Rank: 0.0409 /---/ Weight: 0.141
# 2021-06-01, Rebalancing: VIVT3.SA /---/ Rank: 0.0366 /---/ Weight: 0.108
# 2021-06-01, Buying: HYPE3.SA /---/ Rank: 0.0451 /---/ Weight: 0.084
# 2021-06-01, Buying: TIMS3.SA /---/ Rank: 0.0303 /---/ Weight: 0.000
# 2021-06-01, Buying: HGTX3.SA /---/ Rank: 0.0254 /---/ Weight: 0.020
# 2021-06-01, SELL EXECUTED, Price: 11.20, Cost: 7617.47, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 0.92, Cost: 6813.52, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 3.80, Cost: 143.26, Comm 0.00
# 2021-06-01, Order Margin. Price: 3.75
# 2021-06-01, SELL EXECUTED, Price: 18.29, Cost: 7451.55, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 8.57, Cost: 6144.69, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 2.30, Cost: 1455.90, Comm 0.00
# 2021-06-01, Rebalancing: HGTX3.SA /---/ Rank: 0.0309 /---/ Weight: 0.043
# 2021-06-01, Rebalancing: HYPE3.SA /---/ Rank: 0.0349 /---/ Weight: 0.000
# 2021-06-01, Rebalancing: NTCO3.SA /---/ Rank: 0.0722 /---/ Weight: 0.364
# 2021-06-01, Rebalancing: RADL3.SA /---/ Rank: 0.0527 /---/ Weight: 0.148
# 2021-06-01, Rebalancing: TAEE11.SA /---/ Rank: 0.0396 /---/ Weight: 0.072
# 2021-06-01, Rebalancing: TOTS3.SA /---/ Rank: 0.0446 /---/ Weight: 0.155
# 2021-06-01, Rebalancing: VIVT3.SA /---/ Rank: 0.0421 /---/ Weight: 0.164
# 2021-06-01, Buying: SULA11.SA /---/ Rank: 0.0408 /---/ Weight: 0.000
# 2021-06-01, Buying: EQTL3.SA /---/ Rank: 0.0368 /---/ Weight: 0.054
# 2021-06-01, Buying: TIMS3.SA /---/ Rank: 0.0272 /---/ Weight: 0.000
# 2021-06-01, BUY EXECUTED, Price: 2.53, Cost: 1725.46, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 9.15, Cost: 6144.69, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 10.95, Cost: 2485.65, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 1.10, Cost: 1246.30, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 3.89, Cost: 8365.63, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 3.60, Cost: 6570.00, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 17.90, Cost: 4457.10, Comm 0.00
# 2021-06-01, Order Margin. Price: 2.61
# 2021-06-01, Closing: VIVT3.SA /---/ Rank: 0.0181
# 2021-06-01, Rebalancing: HGTX3.SA /---/ Rank: 0.0656 /---/ Weight: 0.120
# 2021-06-01, Rebalancing: NTCO3.SA /---/ Rank: 0.0765 /---/ Weight: 0.292
# 2021-06-01, Rebalancing: RADL3.SA /---/ Rank: 0.0647 /---/ Weight: 0.157
# 2021-06-01, Rebalancing: TAEE11.SA /---/ Rank: 0.0484 /---/ Weight: 0.165
# 2021-06-01, Rebalancing: TOTS3.SA /---/ Rank: 0.0761 /---/ Weight: 0.150
# 2021-06-01, Buying: BRML3.SA /---/ Rank: 0.0643 /---/ Weight: 0.000
# 2021-06-01, Buying: HYPE3.SA /---/ Rank: 0.0612 /---/ Weight: 0.095
# 2021-06-01, Buying: MULT3.SA /---/ Rank: 0.0497 /---/ Weight: 0.003
# 2021-06-01, Buying: EQTL3.SA /---/ Rank: 0.0496 /---/ Weight: 0.017
# 2021-06-01, SELL EXECUTED, Price: 16.40, Cost: 12097.08, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 3.44, Cost: 5246.00, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 11.75, Cost: 4553.00, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 1.16, Cost: 354.96, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 3.99, Cost: 7812.42, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 4.00, Cost: 887.31, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 11.39, Cost: 7779.37, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 6.54, Cost: 202.74, Comm 0.00
# 2021-06-01, Order Margin. Price: 2.78
# 2021-06-01, Rebalancing: HGTX3.SA /---/ Rank: 0.0903 /---/ Weight: 0.123
# 2021-06-01, Rebalancing: HYPE3.SA /---/ Rank: 0.0851 /---/ Weight: 0.073
# 2021-06-01, Rebalancing: MULT3.SA /---/ Rank: 0.0631 /---/ Weight: 0.000
# 2021-06-01, Rebalancing: NTCO3.SA /---/ Rank: 0.0840 /---/ Weight: 0.197
# 2021-06-01, Rebalancing: RADL3.SA /---/ Rank: 0.0751 /---/ Weight: 0.168
# 2021-06-01, Rebalancing: TAEE11.SA /---/ Rank: 0.0521 /---/ Weight: 0.121
# 2021-06-01, Rebalancing: TOTS3.SA /---/ Rank: 0.0844 /---/ Weight: 0.103
# 2021-06-01, Buying: EZTC3.SA /---/ Rank: 0.1114 /---/ Weight: 0.158
# 2021-06-01, Buying: SULA11.SA /---/ Rank: 0.0885 /---/ Weight: 0.057
# 2021-06-01, Buying: EQTL3.SA /---/ Rank: 0.0500 /---/ Weight: 0.000
# 2021-06-01, SELL EXECUTED, Price: 3.87, Cost: 189.91, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 11.35, Cost: 1457.92, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 6.78, Cost: 196.20, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 13.14, Cost: 6053.62, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 1.25, Cost: 1150.00, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 3.94, Cost: 2751.97, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 4.39, Cost: 3497.44, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 3.05, Cost: 13636.55, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 5.19, Cost: 4966.83, Comm 0.00
# 2021-06-01, Closing: TAEE11.SA /---/ Rank: 0.0787
# 2021-06-01, Rebalancing: EZTC3.SA /---/ Rank: 0.1328 /---/ Weight: 0.099
# 2021-06-01, Rebalancing: HGTX3.SA /---/ Rank: 0.1014 /---/ Weight: 0.122
# 2021-06-01, Rebalancing: HYPE3.SA /---/ Rank: 0.1212 /---/ Weight: 0.081
# 2021-06-01, Rebalancing: MULT3.SA /---/ Rank: 0.0841 /---/ Weight: 0.000
# 2021-06-01, Rebalancing: NTCO3.SA /---/ Rank: 0.1157 /---/ Weight: 0.198
# 2021-06-01, Rebalancing: RADL3.SA /---/ Rank: 0.0963 /---/ Weight: 0.178
# 2021-06-01, Rebalancing: SULA11.SA /---/ Rank: 0.1193 /---/ Weight: 0.033
# 2021-06-01, Rebalancing: TOTS3.SA /---/ Rank: 0.1032 /---/ Weight: 0.060
# 2021-06-01, Buying: IGTA3.SA /---/ Rank: 0.1151 /---/ Weight: 0.120
# 2021-06-01, Buying: EQTL3.SA /---/ Rank: 0.0944 /---/ Weight: 0.107
# 2021-06-01, SELL EXECUTED, Price: 4.08, Cost: 10368.61, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 3.34, Cost: 5166.70, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 4.32, Cost: 531.16, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 13.94, Cost: 45.56, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 13.87, Cost: 388.36, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 1.29, Cost: 1310.64, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 5.09, Cost: 1795.74, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 4.62, Cost: 2831.10, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 11.57, Cost: 11141.91, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 2.86, Cost: 9995.70, Comm 0.00
# 2021-06-01, Closing: EQTL3.SA /---/ Rank: 0.1171
# 2021-06-01, Closing: MULT3.SA /---/ Rank: 0.0899
# 2021-06-01, Rebalancing: EZTC3.SA /---/ Rank: 0.1871 /---/ Weight: 0.114
# 2021-06-01, Rebalancing: HGTX3.SA /---/ Rank: 0.1465 /---/ Weight: 0.096
# 2021-06-01, Rebalancing: HYPE3.SA /---/ Rank: 0.1743 /---/ Weight: 0.065
# 2021-06-01, Rebalancing: IGTA3.SA /---/ Rank: 0.1849 /---/ Weight: 0.158
# 2021-06-01, Rebalancing: NTCO3.SA /---/ Rank: 0.1242 /---/ Weight: 0.135
# 2021-06-01, Rebalancing: RADL3.SA /---/ Rank: 0.1617 /---/ Weight: 0.190
# 2021-06-01, Rebalancing: SULA11.SA /---/ Rank: 0.1702 /---/ Weight: 0.097
# 2021-06-01, Rebalancing: TOTS3.SA /---/ Rank: 0.1794 /---/ Weight: 0.101
# 2021-06-01, Buying: ENEV3.SA /---/ Rank: 0.1813 /---/ Weight: 0.043
# 2021-06-01, Buying: JBSS3.SA /---/ Rank: 0.1403 /---/ Weight: 0.000
# 2021-06-01, SELL EXECUTED, Price: 2.81, Cost: 9995.70, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 7.43, Cost: 6.54, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 3.57, Cost: 1802.85, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 4.74, Cost: 1566.78, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 13.55, Cost: 968.15, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 10.89, Cost: 4628.25, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 13.88, Cost: 3222.28, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 1.49, Cost: 812.94, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 5.74, Cost: 5883.50, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 5.28, Cost: 3416.16, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 95.16, Cost: 4187.04, Comm 0.00
# 2021-06-01, Closing: HYPE3.SA /---/ Rank: 0.1484
# 2021-06-01, Closing: NTCO3.SA /---/ Rank: 0.1044
# 2021-06-01, Closing: RADL3.SA /---/ Rank: 0.1444
# 2021-06-01, Rebalancing: ENEV3.SA /---/ Rank: 0.1598 /---/ Weight: 0.039
# 2021-06-01, Rebalancing: EZTC3.SA /---/ Rank: 0.2179 /---/ Weight: 0.141
# 2021-06-01, Rebalancing: HGTX3.SA /---/ Rank: 0.1839 /---/ Weight: 0.065
# 2021-06-01, Rebalancing: IGTA3.SA /---/ Rank: 0.2273 /---/ Weight: 0.163
# 2021-06-01, Rebalancing: SULA11.SA /---/ Rank: 0.1906 /---/ Weight: 0.141
# 2021-06-01, Rebalancing: TOTS3.SA /---/ Rank: 0.1796 /---/ Weight: 0.090
# 2021-06-01, Buying: MULT3.SA /---/ Rank: 0.1806 /---/ Weight: 0.067
# 2021-06-01, Buying: RENT3.SA /---/ Rank: 0.1754 /---/ Weight: 0.026
# 2021-06-01, Buying: BRML3.SA /---/ Rank: 0.1588 /---/ Weight: 0.040
# 2021-06-01, Buying: TAEE11.SA /---/ Rank: 0.1567 /---/ Weight: 0.228
# 2021-06-01, SELL EXECUTED, Price: 14.57, Cost: 5307.74, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 15.10, Cost: 8258.70, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 1.48, Cost: 11630.63, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 94.21, Cost: 94.21, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 3.84, Cost: 2457.60, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 5.78, Cost: 2581.62, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 12.44, Cost: 87.08, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 6.72, Cost: 3998.40, Comm 0.00
# 2021-06-01, SELL EXECUTED, Price: 5.79, Cost: 817.92, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 9.11, Cost: 7151.35, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 4.23, Cost: 2715.66, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 6.57, Cost: 4237.65, Comm 0.00
# 2021-06-01, BUY EXECUTED, Price: 4.04, Cost: 23537.04, Comm 0.00
# 2021-06-01, Closing: BRML3.SA /---/ Rank: 0.1330
# 2021-06-01, Closing: MULT3.SA /---/ Rank: 0.1591
# 2021-06-01, Closing: RENT3.SA /---/ Rank: 0.1549
# 2021-06-01, Rebalancing: ENEV3.SA /---/ Rank: 0.1712 /---/ Weight: 0.062
# 2021-06-01, Rebalancing: EZTC3.SA /---/ Rank: 0.2057 /---/ Weight: 0.084
# 2021-06-01, Rebalancing: HGTX3.SA /---/ Rank: 0.2045 /---/ Weight: 0.072
# 2021-06-01, Rebalancing: IGTA3.SA /---/ Rank: 0.2436 /---/ Weight: 0.160
# 2021-06-01, Rebalancing: SULA11.SA /---/ Rank: 0.2143 /---/ Weight: 0.138
# 2021-06-01, Rebalancing: TAEE11.SA /---/ Rank: 0.1850 /---/ Weight: 0.219
# 2021-06-01, Rebalancing: TOTS3.SA /---/ Rank: 0.2143 /---/ Weight: 0.105
# ...
# 2020-06-02, BUY EXECUTED, Price: 20.92, Cost: 14288.36, Comm 0.00
# 2020-06-02, BUY EXECUTED, Price: 16.11, Cost: 111626.19, Comm 0.00
# 2020-06-02, BUY EXECUTED, Price: 92.60, Cost: 54263.60, Comm 0.00
# 2020-06-02, BUY EXECUTED, Price: 5.00, Cost: 35375.00, Comm 0.00
# 2020-06-02, Order Margin. Price: 11.89
# 2020-07-01, Rebalancing: AMER3.SA /---/ Rank: 0.1201 /---/ Weight: 0.169
# 2020-07-01, Rebalancing: ENEV3.SA /---/ Rank: 0.0971 /---/ Weight: 0.106
# 2020-07-01, Rebalancing: JHSF3.SA /---/ Rank: 0.1108 /---/ Weight: 0.138
# 2020-07-01, Rebalancing: MGLU3.SA /---/ Rank: 0.1142 /---/ Weight: 0.000
# 2020-07-01, Rebalancing: RADL3.SA /---/ Rank: 0.0736 /---/ Weight: 0.119
# 2020-07-01, Rebalancing: WEGE3.SA /---/ Rank: 0.1263 /---/ Weight: 0.468
# 2020-07-02, Order Margin. Price: 112.02
# 2020-07-02, Order Margin. Price: 11.6
# 2020-07-02, Order Margin. Price: 7.51
# 2020-07-02, SELL EXECUTED, Price: 18.14, Cost: 111610.08, Comm 0.00
# 2020-07-02, SELL EXECUTED, Price: 23.19, Cost: 162459.21, Comm 0.00
# 2020-07-02, BUY EXECUTED, Price: 26.31, Cost: 7024.77, Comm 0.00
# 2020-08-03, Rebalancing: AMER3.SA /---/ Rank: 0.1245 /---/ Weight: 0.216
# 2020-08-03, Rebalancing: ENEV3.SA /---/ Rank: 0.0997 /---/ Weight: 0.150
# 2020-08-03, Rebalancing: JHSF3.SA /---/ Rank: 0.1016 /---/ Weight: 0.045
# 2020-08-03, Rebalancing: MGLU3.SA /---/ Rank: 0.1110 /---/ Weight: 0.000
# 2020-08-03, Rebalancing: RADL3.SA /---/ Rank: 0.0859 /---/ Weight: 0.101
# 2020-08-03, Rebalancing: WEGE3.SA /---/ Rank: 0.1405 /---/ Weight: 0.488
# 2020-08-03, Buying: PRIO3.SA /---/ Rank: 0.0799 /---/ Weight: 0.000
# 2020-08-04, BUY EXECUTED, Price: 125.65, Cost: 226798.25, Comm 0.00
# 2020-08-04, Order Margin. Price: 12.47
# 2020-08-04, BUY EXECUTED, Price: 8.24, Cost: 3106.48, Comm 0.00
# 2020-08-04, SELL EXECUTED, Price: 23.23, Cost: 7043.94, Comm 0.00
# 2020-08-04, SELL EXECUTED, Price: 32.59, Cost: 26721.83, Comm 0.00
# 2020-09-01, Closing: JHSF3.SA /---/ Rank: 0.0717
# 2020-09-01, Closing: RADL3.SA /---/ Rank: 0.0428
# 2020-09-01, Rebalancing: AMER3.SA /---/ Rank: 0.1016 /---/ Weight: 0.097
# 2020-09-01, Rebalancing: ENEV3.SA /---/ Rank: 0.0955 /---/ Weight: 0.093
# 2020-09-01, Rebalancing: MGLU3.SA /---/ Rank: 0.1071 /---/ Weight: 0.045
# 2020-09-01, Rebalancing: WEGE3.SA /---/ Rank: 0.1353 /---/ Weight: 0.476
# 2020-09-01, Buying: KLBN11.SA /---/ Rank: 0.0940 /---/ Weight: 0.255
# 2020-09-01, Buying: SUZB3.SA /---/ Rank: 0.0746 /---/ Weight: 0.035
# 2020-09-02, SELL EXECUTED, Price: 7.05, Cost: 38481.48, Comm 0.00
# 2020-09-02, SELL EXECUTED, Price: 22.36, Cost: 134373.19, Comm 0.00
# 2020-09-02, SELL EXECUTED, Price: 114.32, Cost: 145409.25, Comm 0.00
# 2020-09-02, BUY EXECUTED, Price: 12.47, Cost: 75717.84, Comm 0.00
# 2020-09-02, BUY EXECUTED, Price: 23.93, Cost: 61284.73, Comm 0.00
# 2020-09-02, SELL EXECUTED, Price: 33.23, Cost: 25291.77, Comm 0.00
# 2020-09-02, BUY EXECUTED, Price: 26.06, Cost: 344018.06, Comm 0.00
# 2020-09-02, BUY EXECUTED, Price: 51.00, Cost: 46563.00, Comm 0.00
# 2020-10-01, Closing: SUZB3.SA /---/ Rank: 0.0540
# 2020-10-01, Rebalancing: AMER3.SA /---/ Rank: 0.0769 /---/ Weight: 0.000
# 2020-10-01, Rebalancing: ENEV3.SA /---/ Rank: 0.0826 /---/ Weight: 0.000
# 2020-10-01, Rebalancing: KLBN11.SA /---/ Rank: 0.0754 /---/ Weight: 0.270
# 2020-10-01, Rebalancing: MGLU3.SA /---/ Rank: 0.1056 /---/ Weight: 0.189
# 2020-10-01, Rebalancing: WEGE3.SA /---/ Rank: 0.1342 /---/ Weight: 0.541
# 2020-10-01, Buying: VVAR3.SA /---/ Rank: 0.0862 /---/ Weight: 0.000
# 2020-10-02, SELL EXECUTED, Price: 46.79, Cost: 46563.00, Comm 0.00
# 2020-10-02, SELL EXECUTED, Price: 88.62, Cost: 135652.60, Comm 0.00
# 2020-10-02, SELL EXECUTED, Price: 11.74, Cost: 104201.08, Comm 0.00
# 2020-10-02, BUY EXECUTED, Price: 23.85, Cost: 26568.90, Comm 0.00
# 2020-10-02, BUY EXECUTED, Price: 22.72, Cost: 183691.20, Comm 0.00
# 2020-10-02, BUY EXECUTED, Price: 32.89, Cost: 52755.56, Comm 0.00
# 2020-11-03, Rebalancing: ENEV3.SA /---/ Rank: 0.0809 /---/ Weight: 0.113
# 2020-11-03, Rebalancing: KLBN11.SA /---/ Rank: 0.0736 /---/ Weight: 0.226
# 2020-11-03, Rebalancing: MGLU3.SA /---/ Rank: 0.0976 /---/ Weight: 0.100
# 2020-11-03, Rebalancing: WEGE3.SA /---/ Rank: 0.1452 /---/ Weight: 0.561
# 2020-11-03, Buying: PCAR3.SA /---/ Rank: 0.1648 /---/ Weight: 0.000
# 2020-11-03, Buying: VVAR3.SA /---/ Rank: 0.0814 /---/ Weight: 0.000
# 2020-11-03, Buying: GGBR4.SA /---/ Rank: 0.0688 /---/ Weight: 0.000
# 2020-11-04, Order Margin. Price: 13.8
# 2020-11-04, SELL EXECUTED, Price: 24.42, Cost: 26949.43, Comm 0.00
# 2020-11-04, SELL EXECUTED, Price: 25.36, Cost: 114522.91, Comm 0.00
# 2020-11-04, SELL EXECUTED, Price: 38.86, Cost: 5194.98, Comm 0.00
# 2020-12-01, Closing: KLBN11.SA /---/ Rank: 0.0634
# 2020-12-01, Rebalancing: ENEV3.SA /---/ Rank: 0.0732 /---/ Weight: 0.122
# 2020-12-01, Rebalancing: MGLU3.SA /---/ Rank: 0.0893 /---/ Weight: 0.037
# 2020-12-01, Rebalancing: WEGE3.SA /---/ Rank: 0.1213 /---/ Weight: 0.505
# 2020-12-01, Buying: BRAP4.SA /---/ Rank: 0.0887 /---/ Weight: 0.268
# 2020-12-01, Buying: PRIO3.SA /---/ Rank: 0.0879 /---/ Weight: 0.017
# 2020-12-01, Buying: VALE3.SA /---/ Rank: 0.0818 /---/ Weight: 0.000
# 2020-12-01, Buying: PCAR3.SA /---/ Rank: 0.0728 /---/ Weight: 0.052
# 2020-12-02, SELL EXECUTED, Price: 25.50, Cost: 343637.53, Comm 0.00
# 2020-12-02, BUY EXECUTED, Price: 14.84, Cost: 170066.40, Comm 0.00
# 2020-12-02, SELL EXECUTED, Price: 22.84, Cost: 79017.81, Comm 0.00
# 2020-12-02, SELL EXECUTED, Price: 36.86, Cost: 33521.52, Comm 0.00
# 2020-12-02, BUY EXECUTED, Price: 60.07, Cost: 370992.32, Comm 0.00
# 2020-12-02, BUY EXECUTED, Price: 10.62, Cost: 23597.64, Comm 0.00
# 2020-12-02, BUY EXECUTED, Price: 67.35, Cost: 71997.15, Comm 0.00
# 2021-01-04, Rebalancing: BRAP4.SA /---/ Rank: 0.0815 /---/ Weight: 0.113
# 2021-01-04, Rebalancing: ENEV3.SA /---/ Rank: 0.0684 /---/ Weight: 0.000
# 2021-01-04, Rebalancing: MGLU3.SA /---/ Rank: 0.0895 /---/ Weight: 0.045
# 2021-01-04, Rebalancing: PCAR3.SA /---/ Rank: 0.0646 /---/ Weight: 0.046
# 2021-01-04, Rebalancing: PRIO3.SA /---/ Rank: 0.0825 /---/ Weight: 0.000
# 2021-01-04, Rebalancing: WEGE3.SA /---/ Rank: 0.1060 /---/ Weight: 0.461
# 2021-01-04, Buying: BIDI11.SA /---/ Rank: 0.0908 /---/ Weight: 0.099
# 2021-01-04, Buying: CSNA3.SA /---/ Rank: 0.0907 /---/ Weight: 0.136
# 2021-01-04, Buying: VALE3.SA /---/ Rank: 0.0817 /---/ Weight: 0.000
# 2021-01-04, Buying: KLBN11.SA /---/ Rank: 0.0619 /---/ Weight: 0.100
# 2021-01-05, SELL EXECUTED, Price: 66.32, Cost: 220516.97, Comm 0.00
# 2021-01-05, SELL EXECUTED, Price: 15.65, Cost: 170076.73, Comm 0.00
# 2021-01-05, BUY EXECUTED, Price: 25.08, Cost: 9279.60, Comm 0.00
# 2021-01-05, SELL EXECUTED, Price: 74.11, Cost: 11112.75, Comm 0.00
# 2021-01-05, SELL EXECUTED, Price: 15.48, Cost: 23587.02, Comm 0.00
# 2021-01-05, SELL EXECUTED, Price: 36.95, Cost: 19304.80, Comm 0.00
# 2021-01-05, BUY EXECUTED, Price: 32.12, Cost: 145696.32, Comm 0.00
# 2021-01-05, BUY EXECUTED, Price: 33.21, Cost: 203079.15, Comm 0.00
# 2021-01-05, Order Margin. Price: 25.94
# 2021-02-01, Closing: PCAR3.SA /---/ Rank: -0.0116
# 2021-02-01, Rebalancing: BIDI11.SA /---/ Rank: 0.0931 /---/ Weight: 0.173
# 2021-02-01, Rebalancing: BRAP4.SA /---/ Rank: 0.0632 /---/ Weight: 0.000
# 2021-02-01, Rebalancing: CSNA3.SA /---/ Rank: 0.0814 /---/ Weight: 0.084
# 2021-02-01, Rebalancing: MGLU3.SA /---/ Rank: 0.0790 /---/ Weight: 0.000
# 2021-02-01, Rebalancing: PRIO3.SA /---/ Rank: 0.0653 /---/ Weight: 0.000
# 2021-02-01, Rebalancing: WEGE3.SA /---/ Rank: 0.1113 /---/ Weight: 0.529
# 2021-02-01, Buying: VALE3.SA /---/ Rank: 0.0710 /---/ Weight: 0.008
# 2021-02-01, Buying: SUZB3.SA /---/ Rank: 0.0563 /---/ Weight: 0.180
# 2021-02-01, Buying: ENEV3.SA /---/ Rank: 0.0526 /---/ Weight: 0.026
# 2021-02-02, SELL EXECUTED, Price: 80.52, Cost: 60884.40, Comm 0.00
# 2021-02-02, BUY EXECUTED, Price: 43.25, Cost: 79796.25, Comm 0.00
# 2021-02-02, SELL EXECUTED, Price: 65.25, Cost: 150415.28, Comm 0.00
# 2021-02-02, SELL EXECUTED, Price: 30.24, Cost: 56689.47, Comm 0.00
# 2021-02-02, SELL EXECUTED, Price: 25.28, Cost: 60707.62, Comm 0.00
# 2021-02-02, BUY EXECUTED, Price: 42.57, Cost: 76753.71, Comm 0.00
# 2021-02-02, BUY EXECUTED, Price: 84.62, Cost: 12693.00, Comm 0.00
# 2021-02-02, BUY EXECUTED, Price: 65.34, Cost: 291351.06, Comm 0.00
# 2021-02-02, Order Margin. Price: 17.77
# 2021-03-01, Rebalancing: BIDI11.SA /---/ Rank: 0.1154 /---/ Weight: 0.188
# 2021-03-01, Rebalancing: BRAP4.SA /---/ Rank: 0.0726 /---/ Weight: 0.000
# 2021-03-01, Rebalancing: CSNA3.SA /---/ Rank: 0.0975 /---/ Weight: 0.025
# 2021-03-01, Rebalancing: MGLU3.SA /---/ Rank: 0.0726 /---/ Weight: 0.000
# 2021-03-01, Rebalancing: PRIO3.SA /---/ Rank: 0.0694 /---/ Weight: 0.000
# 2021-03-01, Rebalancing: SUZB3.SA /---/ Rank: 0.0853 /---/ Weight: 0.185
# 2021-03-01, Rebalancing: VALE3.SA /---/ Rank: 0.0875 /---/ Weight: 0.000
# 2021-03-01, Rebalancing: WEGE3.SA /---/ Rank: 0.0867 /---/ Weight: 0.221
# 2021-03-01, Buying: LWSA3.SA /---/ Rank: 0.1520 /---/ Weight: 0.381
# 2021-03-01, Buying: ENEV3.SA /---/ Rank: 0.0668 /---/ Weight: 0.000
# 2021-03-02, SELL EXECUTED, Price: 55.79, Cost: 27175.02, Comm 0.00
# 2021-03-02, SELL EXECUTED, Price: 31.97, Cost: 104511.87, Comm 0.00
# 2021-03-02, SELL EXECUTED, Price: 17.19, Cost: 10.62, Comm 0.00
# 2021-03-02, SELL EXECUTED, Price: 73.83, Cost: 20451.42, Comm 0.00
# 2021-03-02, SELL EXECUTED, Price: 91.49, Cost: 12608.38, Comm 0.00
# 2021-03-02, SELL EXECUTED, Price: 38.37, Cost: 247573.11, Comm 0.00
# 2021-03-02, Order Margin. Price: 29.16
# 2021-04-01, Closing: BRAP4.SA /---/ Rank: 0.1499
# 2021-04-01, Closing: MGLU3.SA /---/ Rank: 0.1477
# 2021-04-01, Closing: SUZB3.SA /---/ Rank: 0.1504
# 2021-04-01, Closing: WEGE3.SA /---/ Rank: 0.1084
# 2021-04-01, Rebalancing: BIDI11.SA /---/ Rank: 0.1939 /---/ Weight: 0.177
# 2021-04-01, Rebalancing: CSNA3.SA /---/ Rank: 0.1924 /---/ Weight: 0.128
# 2021-04-01, Rebalancing: VALE3.SA /---/ Rank: 0.1772 /---/ Weight: 0.142
# 2021-04-01, Buying: LWSA3.SA /---/ Rank: 0.1989 /---/ Weight: 0.140
# 2021-04-01, Buying: PRIO3.SA /---/ Rank: 0.1924 /---/ Weight: 0.070
# 2021-04-01, Buying: MRFG3.SA /---/ Rank: 0.1612 /---/ Weight: 0.277
# 2021-04-01, Buying: ENEV3.SA /---/ Rank: 0.1552 /---/ Weight: 0.067
# 2021-04-01, Buying: USIM5.SA /---/ Rank: 0.1528 /---/ Weight: 0.000
# 2021-04-05, SELL EXECUTED, Price: 64.26, Cost: 60.07, Comm 0.00
# 2021-04-05, SELL EXECUTED, Price: 20.59, Cost: 23.30, Comm 0.00
# 2021-04-05, SELL EXECUTED, Price: 69.46, Cost: 270899.64, Comm 0.00
# 2021-04-05, SELL EXECUTED, Price: 37.95, Cost: 221412.33, Comm 0.00
# 2021-04-05, SELL EXECUTED, Price: 54.34, Cost: 11131.51, Comm 0.00
# 2021-04-05, BUY EXECUTED, Price: 35.84, Cost: 165114.88, Comm 0.00
# 2021-04-05, BUY EXECUTED, Price: 97.90, Cost: 234568.40, Comm 0.00
# 2021-04-05, BUY EXECUTED, Price: 24.64, Cost: 232059.52, Comm 0.00
# 2021-04-05, BUY EXECUTED, Price: 18.40, Cost: 114208.80, Comm 0.00
# 2021-04-05, BUY EXECUTED, Price: 17.76, Cost: 450571.20, Comm 0.00
# 2021-04-05, Order Margin. Price: 16.21
# 2021-05-03, Closing: MRFG3.SA /---/ Rank: 0.1284
# 2021-05-03, Rebalancing: BIDI11.SA /---/ Rank: 0.2268 /---/ Weight: 0.273
# 2021-05-03, Rebalancing: CSNA3.SA /---/ Rank: 0.2189 /---/ Weight: 0.223
# 2021-05-03, Rebalancing: LWSA3.SA /---/ Rank: 0.2055 /---/ Weight: 0.203
# 2021-05-03, Rebalancing: PRIO3.SA /---/ Rank: 0.1499 /---/ Weight: 0.025
# 2021-05-03, Rebalancing: VALE3.SA /---/ Rank: 0.1968 /---/ Weight: 0.275
# 2021-05-03, Buying: GOAU4.SA /---/ Rank: 0.1647 /---/ Weight: 0.000
# 2021-05-03, Buying: BRAP4.SA /---/ Rank: 0.1635 /---/ Weight: 0.000
# 2021-05-03, Buying: BPAC11.SA /---/ Rank: 0.1475 /---/ Weight: 0.000
# 2021-05-04, SELL EXECUTED, Price: 18.93, Cost: 450571.20, Comm 0.00
# 2021-05-04, BUY EXECUTED, Price: 77.50, Cost: 107647.50, Comm 0.00
# 2021-05-04, BUY EXECUTED, Price: 46.23, Cost: 148536.99, Comm 0.00
# 2021-05-04, BUY EXECUTED, Price: 27.73, Cost: 117935.69, Comm 0.00
# 2021-05-04, SELL EXECUTED, Price: 18.64, Cost: 66313.60, Comm 0.00
# 2021-05-04, BUY EXECUTED, Price: 106.84, Cost: 266993.16, Comm 0.00
# 2021-06-01, Rebalancing: BIDI11.SA /---/ Rank: 0.2030 /---/ Weight: 0.246
# 2021-06-01, Rebalancing: CSNA3.SA /---/ Rank: 0.2082 /---/ Weight: 0.278
# 2021-06-01, Rebalancing: LWSA3.SA /---/ Rank: 0.1688 /---/ Weight: 0.078
# 2021-06-01, Rebalancing: PRIO3.SA /---/ Rank: 0.1487 /---/ Weight: 0.051
# 2021-06-01, Rebalancing: VALE3.SA /---/ Rank: 0.1743 /---/ Weight: 0.131
# 2021-06-01, Buying: BPAC11.SA /---/ Rank: 0.1703 /---/ Weight: 0.014
# 2021-06-01, Buying: GOAU4.SA /---/ Rank: 0.1693 /---/ Weight: 0.049
# 2021-06-01, Buying: GGBR4.SA /---/ Rank: 0.1650 /---/ Weight: 0.000
# 2021-06-01, Buying: ENEV3.SA /---/ Rank: 0.1394 /---/ Weight: 0.153
# 2021-06-01, Ending Value 1795107.19
# <h4>Performance Metrics</h4>
#                            Strategy    Benchmark
# -------------------------  ----------  -----------
# Start Period               2005-01-03  2005-01-03
# End Period                 2021-06-01  2021-06-01
# Risk-Free Rate             0.0%        0.0%
# Time in Market             93.0%       100.0%
#
# Cumulative Return          1,695.11%   389.64%
# CAGR﹪                     19.23%      10.16%
#
# Sharpe                     0.84        0.49
# Smart Sharpe               0.81        0.48
# Sortino                    1.15        0.7
# Smart Sortino              1.11        0.68
# Sortino/√2                 0.81        0.5
# Smart Sortino/√2           0.79        0.48
# Omega                      1.18        1.18
#
# Max Drawdown               -60.15%     -59.96%
# Longest DD Days            847         3400
# Volatility (ann.)          25.28%      28.05%
# R^2                        0.4         0.4
# Calmar                     0.32        0.17
# Skew                       -1.28       -0.16
# Kurtosis                   16.21       8.6
#
# Expected Daily %           0.07%       0.04%
# Expected Monthly %         1.47%       0.81%
# Expected Yearly %          18.51%      9.79%
# Kelly Criterion            8.76%       -0.65%
# Risk of Ruin               0.0%        0.0%
# Daily Value-at-Risk        -2.54%      -2.85%
# Expected Shortfall (cVaR)  -2.54%      -2.85%
#
# Gain/Pain Ratio            0.18        0.09
# Gain/Pain (1M)             1.01        0.56
#
# Payoff Ratio               0.95        0.91
# Profit Factor              1.18        1.09
# Common Sense Ratio         1.24        1.06
# CPC Index                  0.62        0.52
# Tail Ratio                 1.05        0.97
# Outlier Win Ratio          4.74        3.57
# Outlier Loss Ratio         3.96        3.61
#
# MTD                        -1.21%      1.62%
# 3M                         10.35%      16.57%
# 6M                         26.16%      16.0%
# YTD                        22.91%      7.51%
# 1Y                         73.2%       46.75%
# 3Y (ann.)                  41.83%      18.46%
# 5Y (ann.)                  42.04%      21.22%
# 10Y (ann.)                 25.93%      7.15%
# All-time (ann.)            19.23%      10.16%
#
# Best Day                   13.0%       14.66%
# Worst Day                  -16.13%     -14.78%
# Best Month                 20.2%       16.97%
# Worst Month                -29.28%     -29.9%
# Best Year                  90.52%      82.66%
# Worst Year                 -41.25%     -41.22%
#
# Avg. Drawdown              -3.69%      -4.14%
# Avg. Drawdown Days         31          58
# Recovery Factor            28.18       6.5
# Ulcer Index                0.16        0.21
# Serenity Index             5.39        0.9
#
# Avg. Up Month              6.33%       5.76%
# Avg. Down Month            -6.33%      -6.93%
# Win Days %                 55.45%      52.15%
# Win Month %                65.76%      57.07%
# Win Quarter %              74.19%      63.64%
# Win Year %                 87.5%       70.59%
# Beta                       0.57        -
# Alpha                      0.13        -
# None
# <h4>5 Worst Drawdowns</h4>
#         Start      Valley         End  Days  Max Drawdown  99% Max Drawdown
# 1  2008-05-21  2008-10-27  2010-09-15   847    -60.148077        -58.296023
# 2  2020-01-24  2020-03-18  2021-01-07   349    -46.713478        -42.398209
# 3  2007-07-20  2008-01-21  2008-04-22   277    -30.148561        -26.199977
# 4  2006-05-10  2006-09-22  2007-05-16   371    -26.397168        -25.001416
# 5  2011-06-06  2011-08-08  2012-03-09   277    -23.817026        -19.369877
# <h4>Strategy Visualization</h4>
